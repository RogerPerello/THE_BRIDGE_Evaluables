# %% [markdown]
# # Importaciones

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train_a = pd.read_csv('df_train_a_cleaned.csv')

# %% [markdown]
# # Observaciones

# %%
df_train_a.head()
# Out:
#    Laptop (ID)  Tech price by country  Numeric version  Bookish  \
# 0          597                      0                1        1
# 1         1173                      4                1        1
# 2         1274                      0                1        0
# 3          252                      0                1        0
# 4           15                      4                1        1
#
#    Sceen size (inches)  Resolution quality  CPU (GHz)  Ram (GB)  Memory (GB)  \
# 0                 15.6                   0        2.5         8         1000
# 1                 15.6                   1        2.5         4          256
# 2                 17.3                   1        2.6        16         1128
# 3                 17.3                   1        2.9        16          256
# 4                 12.0                   2        1.2         8          256
#
#    GPU (GHz)  OS popularity  Weight (kg)  Price (euros)  Touchscreen  \
# ...

# %%
df_train_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Laptop (ID)            912 non-null    int64
#  1   Tech price by country  912 non-null    int64
#  2   Numeric version        912 non-null    int64
#  3   Bookish                912 non-null    int64
#  4   Sceen size (inches)    912 non-null    float64
#  5   Resolution quality     912 non-null    int64
#  6   CPU (GHz)              912 non-null    float64
#  7   Ram (GB)               912 non-null    int64
#  8   Memory (GB)            912 non-null    int64
#  9   GPU (GHz)              912 non-null    float64
#  10  OS popularity          912 non-null    int64
#  11  Weight (kg)            912 non-null    float64
#  12  Price (euros)          912 non-null    float64
#  13  Touchscreen            912 non-null    int64
# ...

# %%
df_train_a.describe()
# Out:
#        Laptop (ID)  Tech price by country  Numeric version     Bookish  \
# count   912.000000             912.000000       912.000000  912.000000
# mean    659.028509               2.766447         0.908991    0.817982
# std     377.497981               1.691735         0.287779    0.386071
# min       1.000000               0.000000         0.000000    0.000000
# 25%     336.750000               2.000000         1.000000    1.000000
# 50%     658.500000               4.000000         1.000000    1.000000
# 75%     985.500000               4.000000         1.000000    1.000000
# max    1320.000000               5.000000         1.000000    1.000000
#
#        Sceen size (inches)  Resolution quality   CPU (GHz)    Ram (GB)  \
# count           912.000000          912.000000  912.000000  912.000000
# mean             15.016667            0.956140    2.306908    8.282895
# std               1.412779            0.889162    0.500568    4.999562
# ...

# %%
df_train_a.corr()
# Out:
#                        Laptop (ID)  Tech price by country  Numeric version  \
# Laptop (ID)               1.000000               0.096454         0.109696
# Tech price by country     0.096454               1.000000         0.069028
# Numeric version           0.109696               0.069028         1.000000
# Bookish                  -0.051203              -0.004655         0.028578
# Sceen size (inches)      -0.053254              -0.047650         0.145210
# Resolution quality       -0.052668               0.105563        -0.114283
# CPU (GHz)                 0.134540               0.071152         0.023114
# Ram (GB)                 -0.016514               0.033258        -0.066009
# Memory (GB)              -0.007579              -0.036220         0.068105
# GPU (GHz)                -0.054261              -0.058945         0.025400
# OS popularity             0.032200               0.126456        -0.006821
# ...
