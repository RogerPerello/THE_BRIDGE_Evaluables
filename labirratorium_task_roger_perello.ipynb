# %% [markdown]
# ###  Pasos a seguir en el proceso de 'scraping':
#
# 1. Encuentra la URL que quieres 'escrapear'.
# 2. Inspecciona la página (código fuente).
# 3. Localiza los datos que necesitas obtener.
# 4. Desarrolla tu código en Python.
#     1. Crea tu sopa
#     2. Busca los elementos que cotienen los datos y extráelos
# 5. Ejecuta tu código y obten los datos.
# 6. Alamacena los datos en el formato requerido.

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np

# %% [markdown]
# ## Caso 1: Scraping de un catálogo: Labirratorium

# %%
def clasifica_cervezas_pagina(cervezas_grid):
    '''Prepara todas las cervezas de una página de labirratorium.com y las clasifica en una lista de diccionarios'''
    lista_cervezas = []
    for cerveza in cervezas_grid:
        URL_cerveza = cerveza.find('a')['href']
        r = requests.get(URL_cerveza)
        if r.status_code == 200:
            soup_cerveza = bs(r.text, 'lxml')
            global current_index
            current_index += 1
            id_cerveza = f'lbt_{current_index}'
            try:
                name = soup_cerveza.find('h1').text
            except:
                name = '(sin nombre)'
            print(f'- Encontrada: {name} (id: {id_cerveza})')
            try:
                price = soup_cerveza.find(class_='current-price').text.split()[0].replace(',','.')
            except:
                price = None
                print('(sin precio)')
            try: 
                descr_short = "".join(soup_cerveza.find(class_='description-short').text.split('\n')).replace(u'\xa0', u' ')
            except:
                descr_short = None
                print('(sin descripcion corta)')
            try:
                descr_full = " ".join(soup_cerveza.find(class_='product-description').text.split())
            except:
                print('(sin descripción larga)')
            try:
                brand = soup_cerveza.find(class_='img img-thumbnail manufacturer-logo')['alt']
            except:
                brand = None
                print('(sin marca)')
            try:
                barcode = soup_cerveza.find(class_='product-reference').text.split()[1]
            except:
                barcode = None
                print('(sin código de barras)')
            try:
                image = soup_cerveza.find(class_='thumb js-thumb selected')['data-image-large-src']
            except:
                image = None
                print('(sin imagen)')
            try:
                features = {}
                features_mess = soup_cerveza.find(class_='data-sheet')
                categories = [category.string for category in features_mess.find_all('dt')]
                values = [value.string for value in features_mess.find_all('dd')]
                for category, value in zip(categories, values):
                    features[category] = value
            except:
                features = None
                print('(sin características)')
            cervezas_dict = {'id_cerveza': id_cerveza,
                                'name':name,
                                'price':price,
                                'descr_short': descr_short,
                                'descr_full': descr_full,
                                'brand': brand,
                                'barcode': barcode,
                                'image': image,
                                'features': features
                            }
            lista_cervezas.append(cervezas_dict)
        else:
            print(f'- Agotada: {cerveza.find("a")("img")[0]["alt"]} (id: {id_cerveza})')
    return lista_cervezas


print('En busca de cervezas:')
lista_maestra_cervezas = []
current_index = 0
for number in range(1, 31):
    URL = f'https://www.labirratorium.com/es/67-cervezas-por-estilo?page={number}'
    r = requests.get(URL)
    soup = bs(r.text, 'lxml')
    cervezas_grid = soup.find_all(class_="product-image")
    print(f'¡A por la página {number}! Llevamos {len(lista_maestra_cervezas)} cervezas.')
    lista_maestra_cervezas += clasifica_cervezas_pagina(cervezas_grid)

df_cervezas = pd.DataFrame(lista_maestra_cervezas)
df_cervezas.replace(r'^\s*$', np.nan, regex=True, inplace=True)

print('\nTabla de cervezas disponibles preparada.')
# Out:
# En busca de cervezas:
# ¡A por la página 1! Llevamos 0 cervezas.
# - Encontrada: SanFrutos Vikingathor Boris Brew (id: lbt_1)
# - Encontrada: Boon Oude Kriek 37,5cl (id: lbt_2)
# - Encontrada: Orval (id: lbt_3)
# - Encontrada: Schneider Aventinus Weizen-Eisbock (id: lbt_4)
# - Encontrada: Aecht Schlenkerla Rauchbier Weizen (id: lbt_5)
# - Encontrada: Samuel Adams Boston Lager (id: lbt_6)
# - Encontrada: Westmalle Dubbel (id: lbt_7)
# - Encontrada: Tripel Karmeliet 33 cl. (id: lbt_8)
# - Encontrada: Weihenstephaner Vitus (id: lbt_9)
# - Encontrada: Anchor Porter (id: lbt_10)
# - Encontrada: Oud Beersel Oude Kriek Vieille 75 cl. (id: lbt_11)
# - Encontrada: Weihenstephaner Korbinian (id: lbt_12)
# ¡A por la página 2! Llevamos 12 cervezas.
# - Encontrada: Aecht Schlenkerla Rauchbier Märzen (id: lbt_13)
# - Encontrada: Samuel Smith Imperial Stout (id: lbt_14)
# - Encontrada: Westmalle Tripel (id: lbt_15)
# - Encontrada: Chimay Azul Grande Réserve 75cl (id: lbt_16)
# - Encontrada: Achel Brune (id: lbt_17)
# - Encontrada: Ayinger Celebrator (id: lbt_18)
# - Encontrada: Pilsner Urquell (id: lbt_19)
# - Encontrada: Aecht Schlenkerla Rauchbier Doppelbock (id: lbt_20)
# - Encontrada: Lindemans Kriek 25 cl. (id: lbt_21)
# - Encontrada: Straffe Hendrik Tripel (id: lbt_22)
# - Encontrada: Chimay Azul 33 cl (id: lbt_23)
# - Encontrada: Achel Blonde (id: lbt_24)
# ¡A por la página 3! Llevamos 24 cervezas.
# - Encontrada: Cantillon Gueuze 100% Lambic Bio 75 cl. (id: lbt_25)
# - Encontrada: Aecht Schlenkerla Rauchbier Urbock (id: lbt_26)
# - Encontrada: DouGall's Raquera (id: lbt_27)
# - Encontrada: Trappistes Rochefort 8 (id: lbt_28)
# - Encontrada: Tripel Karmeliet 75cl (id: lbt_29)
# - Encontrada: Caleya Goma 2 (id: lbt_30)
# - Encontrada: Hanssens Oude Kriek 37,5 cl. (id: lbt_31)
# - Encontrada: Les Trois Mousquetaires Porter Baltique (id: lbt_32)
# - Encontrada: Brewdog Punk IPA (id: lbt_33)
# - Encontrada: Bishops Finger (id: lbt_34)
# - Encontrada: Straffe Hendrik Quadrupel (id: lbt_35)
# - Encontrada: Schneider Tap 6 Aventinus (id: lbt_36)
# ¡A por la página 4! Llevamos 36 cervezas.
# - Encontrada: Blanche de Namur 75cl (id: lbt_37)
# - Encontrada: Trappistes Rochefort 10 (id: lbt_38)
# - Encontrada: Ayinger Altbairisch Dunkel (id: lbt_39)
# - Encontrada: DouGall's Tres Mares (id: lbt_40)
# - Encontrada: Gulden Draak 9000 (id: lbt_41)
# - Encontrada: Chimay Roja (id: lbt_42)
# - Encontrada: Brunehaut Tripel Bio Sin Gluten (id: lbt_43)
# - Encontrada: Laugar Kiskale (id: lbt_44)
# - Encontrada: La Quince Hop Fiction (id: lbt_45)
# - Encontrada: La Chouffe 75 cl. (id: lbt_46)
# - Encontrada: Samichlaus Classic (id: lbt_47)
# - Encontrada: La Trappe Quadrupel (id: lbt_48)
# ¡A por la página 5! Llevamos 48 cervezas.
# - Encontrada: St. Bernardus Wit (id: lbt_49)
# - Encontrada: Caravelle Gringo Mule Mexican Lager (id: lbt_50)
# - Encontrada: Lindemans Oude Gueuze Cuvée René 37,5 cl. (id: lbt_51)
# - Encontrada: Chimay Blanca (id: lbt_52)
# - Encontrada: Maredsous 8 Brune/Bruin (id: lbt_53)
# - Encontrada: Anchor Steam Beer (id: lbt_54)
# - Encontrada: Boon Kriek 25 cl. (id: lbt_55)
# - Encontrada: Cantillon Cuvée Saint-Gilloise (id: lbt_56)
# - Encontrada: Blanche de Namur 33 cl. (id: lbt_57)
# - Encontrada: Caleya Hostia (id: lbt_58)
# - Encontrada: Tegernseer Hell (id: lbt_59)
# - Encontrada: Hirschbrau Höss Doppel-Hirsch (id: lbt_60)
# ¡A por la página 6! Llevamos 60 cervezas.
# - Encontrada: Zeta Zendra (id: lbt_61)
# - Encontrada: Aecht Schlenkerla Helles Lagerbier (id: lbt_62)
# - Encontrada: La Pirata Súria (id: lbt_63)
# - Encontrada: St. Bernardus Prior 8 (id: lbt_64)
# - Encontrada: Hacker Pschorr Münchner Gold (id: lbt_65)
# - Encontrada: Hanssens Framboos - Raspberry Lambic 37,5 cl. (id: lbt_66)
# - Encontrada: La Trappe Dubbel (id: lbt_67)
# - Encontrada: Hitachino Nest Saison Du Japon (id: lbt_68)
# - Encontrada: Aecht Schlenkerla Rauchbier Krausen (id: lbt_69)
# - Encontrada: Oud Beersel Oude Kriek Vieille 37,5 cl. (id: lbt_70)
# - Encontrada: Chimay Roja Premiére 75 cl. (id: lbt_71)
# - Encontrada: 3 Fonteinen Hommage  (season 18|19) Blend No. 33 75 cl. (id: lbt_72)
# ¡A por la página 7! Llevamos 72 cervezas.
# - Encontrada: Duvel (id: lbt_73)
# - Encontrada: Castelló Beer Factory Sant Rock (id: lbt_74)
# - Encontrada: 3 Fonteinen Intens Rood 2018 75 cl. (id: lbt_75)
# - Encontrada: Aecht Schlenkerla Rauchbier Fastenbier - Lentbeer (id: lbt_76)
# - Encontrada: St. Bernardus Tripel (id: lbt_77)
# - Encontrada: Kasteel Barista Chocolate Quad (id: lbt_78)
# - Encontrada: Kloster Andechs Spezial Hell (id: lbt_79)
# - Encontrada: Leffe Brune (id: lbt_80)
# (sin características)
# - Encontrada: Mahr's Bräu aU Ungespundet Naturtrüb (id: lbt_81)
# - Encontrada: Espiga Blonde Sin Gluten (id: lbt_82)
# - Encontrada: Trappistes Rochefort 6 (id: lbt_83)
# - Encontrada: DouGall's Invierno (id: lbt_84)
# ¡A por la página 8! Llevamos 84 cervezas.
# - Encontrada: Espiga Hop Collection Series Mosaic (id: lbt_85)
# - Encontrada: Kwak (id: lbt_86)
# - Encontrada: Cantillon Oude Kriek 75cl (id: lbt_87)
# - Encontrada: Cloudwater Smoked Lager (id: lbt_88)
# - Encontrada: Göller Kellerbier (id: lbt_89)
# - Encontrada: De Cam Framboise Lambiek (id: lbt_90)
# - Encontrada: Westvleteren 8 (id: lbt_91)
# - Encontrada: Ayinger Bairisch Premium-Pils (id: lbt_92)
# - Encontrada: Bacchus Kriekenbier (id: lbt_93)
# - Encontrada: HORAL's Oude Geuze Mega Blend 2022 (id: lbt_94)
# - Encontrada: Ayinger Kellerbier (id: lbt_95)
# - Encontrada: Ayinger Jahrhundert (id: lbt_96)
# ¡A por la página 9! Llevamos 96 cervezas.
# - Encontrada: De Cam Wilde Bosbessen (id: lbt_97)
# - Encontrada: DouGall's Leyenda (id: lbt_98)
# - Encontrada: Westmalle Extra (id: lbt_99)
# - Encontrada: 3 Fonteinen Hommage (season 18|19) Blend No. 42 75 cl. (id: lbt_100)
# - Encontrada: La Corne du Bois des Pendus La Triple (id: lbt_101)
# - Encontrada: 3 Fonteinen Hommage (season 16|17) Blend No. 36 75 cl. (id: lbt_102)
# - Encontrada: Stortebeker Atlantik Ale (id: lbt_103)
# - Encontrada: Gouden Carolus Classic (id: lbt_104)
# - Encontrada: THE GARDEN KELLER HELLES (LATA) 5.5% (id: lbt_105)
# - Encontrada: Sanfrutos / Guineu Caminos paralelos (id: lbt_106)
# - Encontrada: Lote regalo 7 DIAS 7 BIRRAS - SIN ALCOHOL (id: lbt_107)
# - Encontrada: Chimay 150 (Verde) (id: lbt_108)
# ¡A por la página 10! Llevamos 108 cervezas.
# - Encontrada: Schneider Helles Landbier / Bayrisch Hell (id: lbt_109)
# - Encontrada: Young's Double Chocolate Stout (id: lbt_110)
# - Encontrada: Castelló Beer Factory Jano Hop botella (id: lbt_111)
# - Encontrada: Boon Kriek Mariage Parfait 37.5 cl. (id: lbt_112)
# - Encontrada: Maredsous 10 Tripel (id: lbt_113)
# - Encontrada: Delirium Nocturnum (id: lbt_114)
# - Encontrada: Naparbier / Mahr's Bräu Motte (id: lbt_115)
# - Encontrada: Boon Oude Kriek 75 cl. (id: lbt_116)
# - Encontrada: Península Golden Lager (id: lbt_117)
# - Encontrada: Rothaus Pils Tannenzäpfle (id: lbt_118)
# - Encontrada: La Trappe Tripel (id: lbt_119)
# - Encontrada: Lervig No Worries Pineapple (id: lbt_120)
# ¡A por la página 11! Llevamos 120 cervezas.
# - Encontrada: SanFrutos Lager (id: lbt_121)
# - Encontrada: Mc Chouffe 33 cl. (id: lbt_122)
# - Encontrada: Laugar Basurde (id: lbt_123)
# - Encontrada: Tilquin Oude Groseille à Maquereau Verte Tilquin à l'Ancienne 37,5 cl. (id: lbt_124)
# - Encontrada: Cantillon Rosé de Gambrinus 75 cl. (id: lbt_125)
# - Encontrada: Cloudwater Heritage Bock (id: lbt_126)
# - Encontrada: 3 Fonteinen Druif Muscat Bleu (season 19|20) Blend No. 47 (id: lbt_127)
# - Encontrada: Tilquin Oude Gueuze à l’Ancienne 75 cl. (id: lbt_128)
# - Encontrada: CRAK Mundaka (id: lbt_129)
# - Encontrada: Löwenbräu Triumphator (id: lbt_130)
# - Encontrada: 3 Fonteinen Oude Kriek 2019 Blend 120 75cl. (id: lbt_131)
# - Encontrada: Westvleteren 12 (id: lbt_132)
# ¡A por la página 12! Llevamos 132 cervezas.
# - Encontrada: 3 Fonteinen Oude Kriek (season 19|20) Blend No. 16 75 cl. (id: lbt_133)
# - Encontrada: Rochefort Triple Extra (id: lbt_134)
# - Encontrada: Cloudwater Vienna Lager (id: lbt_135)
# - Encontrada: Lote regalo CERVEZAS SIN GLUTEN:  7 DIAS 7 BIRRAS (id: lbt_136)
# - Encontrada: 3 Fonteinen Oude Kriekenlambik (season 20|21) Blend No. 15 75 cl. (id: lbt_137)
# - Encontrada: Hoegaarden Grand cru (id: lbt_138)
# - Encontrada: HItachino Nest Non Ale (id: lbt_139)
# - Encontrada: Samuel Smith India Ale (id: lbt_140)
# - Encontrada: 3 Fonteinen Oude Kriek PX Geturfd (season 19|20) Blend No. 75 75 cl. (id: lbt_141)
# - Encontrada: 3 Fonteinen Oude Geuze Cuvée Armand & Gaston 37,5 cl. (id: lbt_142)
# - Encontrada: 3 Fonteinen Oude Kriek PX Geturfd (season 19|20) Blend No. 75 37,5 cl. (id: lbt_143)
# - Encontrada: Oud Beersel Oude Geuze Vieille 75 cl. (id: lbt_144)
# ¡A por la página 13! Llevamos 144 cervezas.
# - Encontrada: Oud Beersel Green Walnut (id: lbt_145)
# - Encontrada: Gulden Draak Smoked (id: lbt_146)
# - Encontrada: The Kernel Biere De Saison Raspberry (id: lbt_147)
# - Encontrada: Cloudwater Schwarzbier (id: lbt_148)
# - Encontrada: Lindemans Cassis (id: lbt_149)
# - Encontrada: Althaia Mediterranean IPA Sin Alcohol (id: lbt_150)
# - Encontrada: Lindemans Gueuze 25 cl. (id: lbt_151)
# - Encontrada: Alvinne Cuvée Freddy (id: lbt_152)
# - Encontrada: 3 Fonteinen Oude Geuze Cuvée Armand & Gaston (season 19|20) Blend No. 5 75 cl. (id: lbt_153)
# - Encontrada: DouGall's Session Stout (id: lbt_154)
# - Encontrada: Dieu du Ciel Solstice d'Hiver (id: lbt_155)
# - Encontrada: Keizer Karel Charles Quint Rouge Rubis (id: lbt_156)
# ¡A por la página 14! Llevamos 156 cervezas.
# - Encontrada: De Cam Oude Geuze 37,5 cl. (id: lbt_157)
# - Encontrada: Hanssens Oude Gueuze 75 cl. (id: lbt_158)
# - Encontrada: Caleya Asturies Pale Ale (id: lbt_159)
# - Encontrada: Lindemans Faro (id: lbt_160)
# - Encontrada: Leffe Blond 0.0% (id: lbt_161)
# - Encontrada: Cata De Cervezas De Navidad (id: lbt_162)
# - Encontrada: 3 Fonteinen Framboos 2017 (id: lbt_163)
# - Encontrada: DouGall's IPA 4 (id: lbt_164)
# - Encontrada: Tempest Brave New World (id: lbt_165)
# - Encontrada: Laugar Kendu Weissbier Sin Alcohol (id: lbt_166)
# - Encontrada: Schneider Weisse Original TAP 7 (id: lbt_167)
# - Encontrada: St. Louis Premium Framboise (id: lbt_168)
# ¡A por la página 15! Llevamos 168 cervezas.
# - Encontrada: Augustiner Weissbier (id: lbt_169)
# - Encontrada: Lammsbrau Sin alcohol/Sin Gluten (id: lbt_170)
# (sin marca)
# (sin características)
# - Encontrada: Belhaven Scottish Ale (id: lbt_171)
# - Encontrada: Clausthaler Unfiltered - Sin filtrar  - Sin alcohol (id: lbt_172)
# (sin marca)
# (sin características)
# - Encontrada: Schneider Tap 1 Weisse Weizen Hell (id: lbt_173)
# - Encontrada: DouGall's Happy Otter (id: lbt_174)
# - Encontrada: La Quince God Save the Session IPA Gluten free (id: lbt_175)
# - Encontrada: La Quince Weizenland (id: lbt_176)
# - Encontrada: Duvel Tripel Hop Citra (id: lbt_177)
# - Encontrada: Troubadour Magma (id: lbt_178)
# - Encontrada: Lervig No Worries Driving Home For Christmas (id: lbt_179)
# - Encontrada: Naparbier Paradise? Lata 33 cl. (id: lbt_180)
# ¡A por la página 16! Llevamos 180 cervezas.
# - Encontrada: Hitachino Nest White Ale (id: lbt_181)
# - Encontrada: DouGall's IPA 6 (id: lbt_182)
# - Encontrada: Kasteel Cuvée du Chateau (id: lbt_183)
# - Encontrada: Riegele Augsburger Herren Pils (id: lbt_184)
# - Encontrada: Schneider Weisse Tap 3 Mein Alkoholfreies 33 cl. (id: lbt_185)
# - Encontrada: SanFrutos Tutiplén (id: lbt_186)
# - Encontrada: Laugar Punkarra (botella) (id: lbt_187)
# - Encontrada: Delirium Noel / Christmas 2022 (id: lbt_188)
# - Encontrada: Gauloise Christmas 2022 33cl (id: lbt_189)
# - Encontrada: Kloster Andechs Weissbier Hell (id: lbt_190)
# - Encontrada: Calendario de Adviento La Quince / La Pirata / Guineu 2022 (id: lbt_191)
# - Encontrada: Samuel Smith Nut Brown Ale (id: lbt_192)
# ¡A por la página 17! Llevamos 192 cervezas.
# - Encontrada: Península Czech Style Lager (id: lbt_193)
# - Encontrada: La Quince Roots (id: lbt_194)
# - Encontrada: Staropramen Premium (id: lbt_195)
# - Encontrada: Tilquin Oude Pinot Gris Tilquin à L'Ancienne 75 cl. (id: lbt_196)
# - Encontrada: THE GARDEN OKTOBEER PILSEN (LATA) 5.5% (id: lbt_197)
# - Encontrada: Basqueland Arraun Lata (id: lbt_198)
# - Encontrada: Saison Dupont 75 cl (id: lbt_199)
# - Encontrada: Leffe Blonde (id: lbt_200)
# - Encontrada: Tilquin Oude Groseille à Maquereau Verte Tilquin à l'Ancienne 75 cl. (id: lbt_201)
# - Encontrada: Brewdog Elvis Juice (id: lbt_202)
# - Encontrada: Naparbier ZZ Lata 33 cl. (id: lbt_203)
# - Encontrada: Wychwood King Goblin (id: lbt_204)
# ¡A por la página 18! Llevamos 204 cervezas.
# - Encontrada: Flying Dog Raging Bitch (id: lbt_205)
# - Encontrada: Lo Vilot Benzin (id: lbt_206)
# - Encontrada: Bush Scaldis Ambree (id: lbt_207)
# - Encontrada: Schneider Festweisse Tap 4 (id: lbt_208)
# - Encontrada: Brunehaut Saison Bio Sin Gluten (id: lbt_209)
# - Encontrada: La Chouffe Blanche (id: lbt_210)
# - Encontrada: Hoegaarden Le Fruit Defendu (id: lbt_211)
# - Encontrada: DOUGALL´S MEGASETH (id: lbt_212)
# (sin marca)
# - Encontrada: Tilquin Oude Gewurzt Tilquin à L’Ancienne (2020-2021) 75 cl. (id: lbt_213)
# - Encontrada: Brewski Sansa Session IPA (id: lbt_214)
# - Encontrada: Gross Gaupasa (id: lbt_215)
# - Encontrada: Tilquin Oude Sureau Tilquin à L’Ancienne (2020-2021) 75 cl. (id: lbt_216)
# ¡A por la página 19! Llevamos 216 cervezas.
# - Encontrada: Tilquin Oude Sureau Tilquin à L’Ancienne (2020-2021) 37,5 cl. (id: lbt_217)
# - Encontrada: La Calavera Kerosene (id: lbt_218)
# - Encontrada: Samuel Smith Taddy Porter (id: lbt_219)
# - Encontrada: Laugar Basatia (id: lbt_220)
# - Encontrada: Barbãr (id: lbt_221)
# - Encontrada: Freddo Fox One Way Ticket (id: lbt_222)
# - Encontrada: De Ranke XX Bitter (id: lbt_223)
# - Encontrada: Sierra Nevada Tropical Torpedo (id: lbt_224)
# - Encontrada: Sanfrutos Puñales (id: lbt_225)
# - Encontrada: Cloudwater Pampel Weisse Wheat (id: lbt_226)
# - Encontrada: Vedett Extra White (id: lbt_227)
# (sin marca)
# - Encontrada: Troubadour Imperial Stout (id: lbt_228)
# ¡A por la página 20! Llevamos 228 cervezas.
# - Encontrada: Alvinne Morpheus Wit (id: lbt_229)
# (sin características)
# - Encontrada: Dúa Sparkling Beer Violette (id: lbt_230)
# - Encontrada: Tommie Sjef Bitter (id: lbt_231)
# - Encontrada: Meta Wacho (id: lbt_232)
# - Encontrada: Alvinne Morpheus Saison (id: lbt_233)
# (sin características)
# - Encontrada: The Kernel India Pale Ale Citra Centennial (id: lbt_234)
# - Encontrada: Naparbier Aker Lata 33 cl. (id: lbt_235)
# - Encontrada: Kwak 75 cl. (id: lbt_236)
# - Encontrada: Struise Pannepot 2021 (id: lbt_237)
# - Encontrada: DouGall’s IPA 9 (id: lbt_238)
# - Encontrada: Laugar Kide (id: lbt_239)
# - Encontrada: La Chouffe - Estuche 4 botellas + Copa (id: lbt_240)
# (sin características)
# ¡A por la página 21! Llevamos 240 cervezas.
# - Encontrada: Gouden Carolus Christmas / Noel 2022 75 cl. (id: lbt_241)
# - Encontrada: La Chouffe N'Ice 2022 33 cl. (id: lbt_242)
# - Encontrada: La Chouffe N'Ice 2022 75 cl. (id: lbt_243)
# - Encontrada: CRAK Guerrilla (id: lbt_244)
# - Encontrada: Cherry Chouffe (id: lbt_245)
# - Encontrada: Dieu du Ciel! Péché Mortel (id: lbt_246)
# - Encontrada: DouGall's 942 (id: lbt_247)
# - Encontrada: Basqueland Imparable IPA Lata (id: lbt_248)
# - Encontrada: Magic Rock Fantasma (id: lbt_249)
# - Encontrada: Wychwood Ginger Beard (id: lbt_250)
# - Encontrada: Kasteel Rouge (id: lbt_251)
# - Encontrada: Basqueland Freebird Lata (id: lbt_252)
# ¡A por la página 22! Llevamos 252 cervezas.
# - Encontrada: Lervig Sour Suzy (id: lbt_253)
# - Encontrada: DouGall's Doble IPA (id: lbt_254)
# - Encontrada: La Calavera Tequila Sunrise (id: lbt_255)
# - Encontrada: La Calavera The Walking Coeliacs Gluten Free (id: lbt_256)
# - Encontrada: Brunehaut Blonde Bio Sin Gluten (id: lbt_257)
# - Encontrada: Brunehaut Amber Bio Sin Gluten (id: lbt_258)
# - Encontrada: De Ranke Cuvee de Ranke 75cl (id: lbt_259)
# - Encontrada: Basqueland Zumo (id: lbt_260)
# - Encontrada: Duchesse de Bourgogne Cherry Chocolate (id: lbt_261)
# - Encontrada: Althaia Mediterranean Lager (id: lbt_262)
# - Encontrada: SOMA JUICY JUNGLE (id: lbt_263)
# - Encontrada: Garage Fractal Spectrum (id: lbt_264)
# ¡A por la página 23! Llevamos 264 cervezas.
# - Encontrada: Caleya Goma 2 Lata 44 cl. (id: lbt_265)
# - Encontrada: Brugse Zot (id: lbt_266)
# - Encontrada: Naparbier Zukua (id: lbt_267)
# - Encontrada: Basqueland AUPA Lata (id: lbt_268)
# - Encontrada: Samuel Smith Winter Welcome Ale 2022 - 2023 (id: lbt_269)
# - Encontrada: Bacchus Oud Bruin (id: lbt_270)
# - Encontrada: Robinsons Trooper Day of the Dead (id: lbt_271)
# - Encontrada: Bombardier Amber Beer / Premium British Ale (id: lbt_272)
# - Encontrada: Sharp's Doom Bar (id: lbt_273)
# - Encontrada: Wychwood Dry Neck (id: lbt_274)
# - Encontrada: Gulden Draak Imperial Stout (id: lbt_275)
# - Encontrada: Duvel 666 (id: lbt_276)
# ¡A por la página 24! Llevamos 276 cervezas.
# - Encontrada: La Quince / BrewHeart Spaceman (id: lbt_277)
# - Encontrada: La Quince LLIPA! (lata) (id: lbt_278)
# - Encontrada: Dougall ́s Dúo HBC 586 Cryo POP (id: lbt_279)
# - Encontrada: Pohjala Helge (id: lbt_280)
# - Encontrada: Caleya Fruit Smooch Tropic (id: lbt_281)
# - Encontrada: Sanfrutos Rave DDH IPA (id: lbt_282)
# (sin marca)
# - Encontrada: Gross Egun Ero (id: lbt_283)
# - Encontrada: Península Tormenta Tropikal (id: lbt_284)
# (sin marca)
# - Encontrada: Península La Gorda 2022 (id: lbt_285)
# (sin marca)
# - Encontrada: Pyrene Trainshopping (id: lbt_286)
# - Encontrada: Verdant People, Money, Space, Time (id: lbt_287)
# - Encontrada: Laugar Bitxia (id: lbt_288)
# ¡A por la página 25! Llevamos 288 cervezas.
# - Encontrada: Flying Dog Royal Crush Orange Crush Ale (id: lbt_289)
# - Encontrada: Samuel Smith Organic Chocolate Stout (id: lbt_290)
# - Encontrada: MONTSENY MALTA (id: lbt_291)
# (sin marca)
# - Encontrada: Castelló Beer Factory Engendro (id: lbt_292)
# - Encontrada: La Quince / Drunken Bros Misfit Pumpkins (id: lbt_293)
# - Encontrada: La Pirata Black Block (id: lbt_294)
# - Encontrada: De Ranke Kriek 75cl (id: lbt_295)
# - Encontrada: Samuel Smith Oatmeal Stout (id: lbt_296)
# - Encontrada: Früh Kölsch (id: lbt_297)
# - Encontrada: La Quince / Juguetes Perdidos Get Lucky (id: lbt_298)
# - Encontrada: Laugar / Malte The Doom Series: Funeralopolis 2022 (id: lbt_299)
# - Encontrada: La Quince Wild Sour IV - Grape Ale BA (id: lbt_300)
# ¡A por la página 26! Llevamos 300 cervezas.
# - Encontrada: Hitachino Nest Espresso Stout (id: lbt_301)
# - Encontrada: Wild Nation Zubiete 37,5 cl. (id: lbt_302)
# - Encontrada: Wild Nation Beraskola 75 cl. (id: lbt_303)
# - Encontrada: Wild Nation Zaldu 75 cl. (id: lbt_304)
# - Encontrada: Wild Nation Sandamendi 75 cl. (id: lbt_305)
# - Encontrada: Amundsen DONUT SERIES - Red Velvet Cake with Vanilla and White Chocolate Glaze (id: lbt_306)
# - Encontrada: Tommie Sjef Cuvée (id: lbt_307)
# - Encontrada: Tilquin / Rulles Stout Rullquin (id: lbt_308)
# - Encontrada: Wychwood Diceman (id: lbt_309)
# - Encontrada: Espiga Brave Lands (id: lbt_310)
# - Encontrada: Espiga Harvest Hour (id: lbt_311)
# - Encontrada: Espiga Running Away (id: lbt_312)
# (sin características)
# ¡A por la página 27! Llevamos 312 cervezas.
# - Encontrada: Garage / 3Marks / Nomad Current (id: lbt_313)
# - Encontrada: Laugar Aupa Tovarisch 2022 (id: lbt_314)
# - Encontrada: SanFrutos Ítaca (id: lbt_315)
# - Encontrada: Amundsen Christmas Morning (id: lbt_316)
# - Encontrada: Amundsen Super Santa 2022 (id: lbt_317)
# - Encontrada: Lervig Original Sin (id: lbt_318)
# - Encontrada: Stigbergets Amazing Haze (id: lbt_319)
# - Encontrada: La Quince / Guineu Black Barley (Oloroso Barrel Aged) (id: lbt_320)
# - Encontrada: SanFrutos / Mala Gissona Arrebato (id: lbt_321)
# - Encontrada: Lervig Tasty Juice Extra Juicy (id: lbt_322)
# - Encontrada: Brewski El Rafe (id: lbt_323)
# - Encontrada: Polly's Brew Deluxe Edition (id: lbt_324)
# ¡A por la página 28! Llevamos 324 cervezas.
# - Encontrada: La Quince LA LA LOVE YOU (id: lbt_325)
# - Encontrada: Crak Plain Of The Po (id: lbt_326)
# - Encontrada: Garage Soup IPA (id: lbt_327)
# - Encontrada: Anchor Tropical Hazy IPA (id: lbt_328)
# - Encontrada: FrauGruber Dimension Shifter (id: lbt_329)
# - Encontrada: Gross / Kent Falls Honey Moon (id: lbt_330)
# - Encontrada: La Quince Chiwaka Loves Riwaka (id: lbt_331)
# - Encontrada: Pyrene / Cosmic Interestellar Hops (id: lbt_332)
# - Encontrada: Zeta Juvara (id: lbt_333)
# - Encontrada: FRAUGRUBER LIQUID ART NEW ENGLAND DIPA (id: lbt_334)
# (sin características)
# - Encontrada: Polly's Brew/ Funky Fluid - CHAMALEON (id: lbt_335)
# - Encontrada: Sanfrutos Oro Negro (id: lbt_336)
# ¡A por la página 29! Llevamos 336 cervezas.
# - Encontrada: Wychwood Hobgoblin IPA (id: lbt_337)
# - Encontrada: La Quince / Guineu Vanilla Black Velvet 2022 (id: lbt_338)
# - Encontrada: O’Hara’s Irish Stout Nitro (id: lbt_339)
# - Encontrada: Basqueland Barrel Works Bourbon (id: lbt_340)
# - Encontrada: Sanfrutos Eterno Retorno (id: lbt_341)
# - Encontrada: La Quince / Guineu Choco & Vanilla (id: lbt_342)
# - Encontrada: Lervig Stoutella By Rackhouse (id: lbt_343)
# - Encontrada: Lervig / Pohjala Night By the Lake By Rackhouse (id: lbt_344)
# - Encontrada: Galway Bay / La Pirata Sixty Ships Down (id: lbt_345)
# - Encontrada: MONTSENY MALA VIDA BRANDY (id: lbt_346)
# (sin marca)
# - Encontrada: Sanfrutos Nictofilia (id: lbt_347)
# - Encontrada: Garage / Finback Muted Sophisticated  MASH 22 (id: lbt_348)
# ¡A por la página 30! Llevamos 348 cervezas.
# - Encontrada: Dougall's Abyssal (id: lbt_349)
# - Encontrada: Lervig Tasty Juice (id: lbt_350)
# - Encontrada: Garage / Hudson Valley Thistleweed MASH 22 (id: lbt_351)
# - Encontrada: Athletic Brewing Run Wild IPA - SIn Alcohol (id: lbt_352)
# - Encontrada: MONTSENY LUPULUS (id: lbt_353)
# (sin marca)
# - Encontrada: MONTSENY ECO (id: lbt_354)
# (sin marca)
# - Encontrada: St. Louis Premium Gueuze (id: lbt_355)
# (sin marca)
# - Encontrada: Garage / Hudson Valley Clay Life MASH 22 (id: lbt_356)
# - Encontrada: Garage / Finback Distant Lands MASH 22 (id: lbt_357)
#
# Tabla de cervezas disponibles preparada.

# %%
df_cervezas
# Out:
#     id_cerveza                                      name price  \
# 0        lbt_1          SanFrutos Vikingathor Boris Brew  3.35
# 1        lbt_2                    Boon Oude Kriek 37,5cl  7.15
# 2        lbt_3                                     Orval  2.50
# 3        lbt_4        Schneider Aventinus Weizen-Eisbock  2.85
# 4        lbt_5        Aecht Schlenkerla Rauchbier Weizen  2.70
# ..         ...                                       ...   ...
# 352    lbt_353                          MONTSENY LUPULUS  2.00
# 353    lbt_354                              MONTSENY ECO  2.60
# 354    lbt_355                  St. Louis Premium Gueuze  1.90
# 355    lbt_356  Garage / Hudson Valley Clay Life MASH 22  4.90
# 356    lbt_357    Garage / Finback Distant Lands MASH 22  4.90
#
#                                            descr_short  \
# 0                                        Indian Dunkel
# 1                                       Lambic / Kriek
# 2                                     Belgian Pale Ale
# 3    Cerveza de color medio oscuro, aromas alcohóli...
# 4                                                  NaN
# ..                                                 ...
# 352                                   Blonde Ale 5,4%
# 353                  Blonde Ale 5.4% ABV.29 IBU. 9 EBC
# 354                                    Gueuze 4.5% ABV
# 355  Extra Special Bitter 5,2% Lúpulo East Kent Gol...
# 356  Golden Ale 4,2% Lúpulos: Motueka, Cascade, Eas...
#
#                                             descr_full              brand  \
# 0    Cerveza de 8.2% ABV intensa, oscura y muy lupu...  Cerveza Sanfrutos
# 1    Cerveza de fermentación espontánea (Lambic) de...  Brouwerij F. Boon
# 2    Orval es una cerveza tipo ale y es la que prin...              Orval
# 3    Cerveza de color medio oscuro, aromas alcohóli...          Schneider
# 4    Rauchbier (cerveza ahumada) de trigo con 5.2% ...        Schlenkerla
# ..                                                 ...                ...
# 352  Blonde Ale 5,4% 29 IBU con lúpulos Cascade, fu...               None
# 353  Blonde Ale 5.4% ABV. 29 IBU. 9 EBC Con malta P...               None
# 354  Madurada en barrica de roble, esta lambic belg...               None
# 355  Extra Special Bitter 5,2% Lúpulo East Kent Gol...    Garage Beer Co.
# 356  Golden Ale 4,2% Lúpulos: Motueka, Cascade, Eas...    Garage Beer Co.
#
#     barcode                                              image  \
# 0       831  https://www.labirratorium.com/27941-large_defa...
# 1       284  https://www.labirratorium.com/19351-large_defa...
# 2       199  https://www.labirratorium.com/385-large_defaul...
# 3       183  https://www.labirratorium.com/366-large_defaul...
# 4       181  https://www.labirratorium.com/364-large_defaul...
# ..      ...                                                ...
# 352   19748  https://www.labirratorium.com/33088-large_defa...
# 353   19750  https://www.labirratorium.com/33090-large_defa...
# 354   19821  https://www.labirratorium.com/33266-large_defa...
# 355   19836  https://www.labirratorium.com/33288-large_defa...
# 356   19838  https://www.labirratorium.com/33286-large_defa...
#
#                                               features
# 0    {'Estilo': 'DUNKEL', 'Origen': 'Segovia', '% A...
# 1    {'Estilo': 'KRIEK', 'Origen': 'Bélgica', '% Al...
# 2    {'Estilo': 'BELGIAN PALE ALE', 'Origen': 'Bélg...
# 3    {'Origen': 'Alemania', '% Alc. Exacto': '12', ...
# 4    {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# ..                                                 ...
# 352  {'Estilo': 'BLOND ALE', '% Alc.': 'BAJO (2.5-4...
# 353  {'Estilo': 'BLOND ALE', '% Alc.': 'BAJO (2.5-4...
# 354  {'Estilo': 'GUEUZE', 'Origen': 'Bélgica', '% A...
# 355  {'Estilo': 'ENGLISH BITTER', '% Alc.': 'MEDIO ...
# 356  {'Estilo': 'GOLDEN ALE', '% Alc.': 'MEDIO (4-6...
#
# [357 rows x 9 columns]
