# %% [markdown]
# # Práctica 1: INTRODUCCIÓN A LOS DATOS

# %%
import json
import pandas as pd
import folium
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pyproj as proj
import warnings

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# **Muestra un ejemplo de datos estructurados, otro de datos semi-estructurados, y otro de datos no-estructurados y justifica por qué los has clasificado así.
# Los ejemplos deben ser extraídos de la página web del catálogo de datos abiertos de Valencia** (https://portaldadesobertes.gva.es/es).
#
#
# NOTA: No es necesario que se compartan los datasets junto con la entrega de la PAC, es suficiente con referenciarlos, hacer una captura del dataset o copiar algunas instancias del dataset.
# Lo más importante es que quede referenciado el dataset y justificado por qué se ha clasificado como estructurado, semi-estructurado o no-estructurados.

# %%
# Estructurado (https://dadesobertes.gva.es/es/dataset/edu-alu-gen-2021/resource/0467aa69-18f7-4bb1-8d8d-7df4293294cd)

img = mpimg.imread(r'.\estructurado.PNG')
imgplot = plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Semiestructurado (https://dadesobertes.gva.es/es/dataset/edu-alu-gen-2021/resource/0467aa69-18f7-4bb1-8d8d-7df4293294cd)

img = mpimg.imread(r'.\semiestructurado.PNG')
imgplot = plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Desestructurado (https://dadesobertes.gva.es/es/dataset/padro-municipal-continu-explotacio-estadistica-per-districtes-i-seccions-2021-v3)

img = mpimg.imread(r'.\desestructurado.PNG')
imgplot = plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# El formato JSON (JavaScript Object Notation) es un formato de texto sencillo para el intercambio de datos, ampliamente utilizado. En Python, la librería **json** permite abrir datos de este tipo, asignarlos a una variable y trabajar con ellos.
#
# La función **json.load()** permite parsear una cadena JSON y convertirla en un diccionario de Python.
#
# De forma inversa, si tenemos un objeto python, lo podemos convertir en una cadena JSON utilizando **json.dumps()**.
#
# Una vez cargado el JSON, éste puede ser visualizado manteniendo la identación propia del JSON para hacer más fácil su interpretación mediante la modificación de los argumentos de la función json.dumps()
#
# _Ejemplo:_
#
# ```
# import json
#
# #ejemplo_json es una cadena json
# parsed_json = json.loads(ejemplo_json)
# print(json.dumps(parsed_json, indent=4, sort_keys=True))
#
# ```
#
# Ejemplo de leer un JSON desde un archivo de texto o archivo JSON.
#
#
# ```
# with open('nombre_archivo.txt') as archivo_json:
#     parsed_json = json.load(archivo_json)
#
# ```

# %% [markdown]
# **En este ejercicio se va a trabajar con dos datasets en formato json: `consulados.json` y `altas_hospitalarias.json`. El primero de ellos hace referencia al listado de los consulados que se pueden encontrar en la ciudad de Barcelona. El segundo es el registro de las altas hospitalarias por causa de hospitalización y sexo.**
#
# **Para el dataset `consulados.json`, se pide:**
# - **Cargar el fichero y visualizarlo correctamente, revisando que se sigue la identación y por tanto se facilita su interpretación.**
#
# - **¿Qué campos tiene?¿de qué tipo son?**
# - **Transformar el json a un dataframe apoyándote en la librería pandas, de forma que cada campo diferente sea una columna.**
#
# - **Guardar el dataframe generado como csv.**
# - **Cargar el csv guardado en el punto anterior.**
# - **Visualizar las 5 primeras filas (df.head())**
# - **Obtener las dimensiones del dataframe (df.shape)**
# - **¿Mantiene los mismos campos el csv generado y el json facilitado con el enunciado?**
# - **¿Con qué tipo de dato asocia pandas a cada columna del dataframe? (df.types)**
#
# **Para el dataset `altas_hospitalarias.json`, se pide:**
# - **Cargar el fichero y visualizarlo correctamente, revisando que se sigue la identación y por tanto se facilita su interpretación.**
#
# - **¿Qué campos tiene?¿de qué tipo son?**
# - **Transformar el json a un dataframe apoyándote en la librería pandas, de forma que las columnas resultantes sean 3: nombre de la causa, sexo, valor del número de altas. Para ello, deberás revisar el dataset y seleccionar los campos de interés que se quieren incluir en el dataframe. En la siguiente imagen se puede ver la forma del dataframe esperado:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **¿Cuántas categorías distintas puede tener la variable relativa al sexo? ¿Cuáles son? A partir del dataframe completo, obten tantos dataframes como número de categorías distintas de la variable relativa al sexo haya.**
#
#  - Por ejemplo si hay dos categorías, A y B, deberéis obtener dos dataframes: uno que considere todas las instancias de 'sexo' igual a A y otro dataframe que considere todas las instancias de 'sexo' igual a B.

# %% [markdown]
# NOTA: Se recomienda que se explore la librería json además de la librería pandas que, aunque la veremos con más detalle en el siguiente reto, en esta PAC utilizaremos las instrucciones básicas de cargar un csv en un dataframe (**pd.read_csv()**), visualizar las las primeras filas de un dataframe (**df.head()**), comprobar el tipo de dato que es cada columna del dataframe (**df.dtypes**), cambiar el tipo de dato de una columna (**df['nombre_columna'].astype(tipo_dato)**), y guardar dataframes como csv (**df.to_csv()**).
#
#
#
#
# ---

# %% [markdown]
# ---
# **DATA CONSULADOS**

# %%
# CArgar el json y visualizarlo (considerando la identación)

json_file_path = r'./consulados.json'
with open(json_file_path, 'r') as j:
     contents = json.load(j)

dict_consulados = json.loads(contents)

print(len(dict_consulados))

print(len(dict_consulados['0']))

for element in dict_consulados['0']:
     print(type(element))
# Out:
# 92
# 26
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# **¿Cuántos registros tiene? ¿Que campos tiene cada registro? ¿de qué tipo son?**

# %% [markdown]
# Respuesta: Tiene 92 registros. Cada uno tiene 26 registros. Son strings.

# %%
# Transformar el json a un dataframe apoyándote en la librería pandas.

df_consulados = pd.DataFrame(dict_consulados).T

# %%
# Guardar el dataframe generado como csv.

df_consulados.to_csv(r'./consulados.csv')

# %%
#Cargar el csv guardado en el punto anterior.

df_consulados = pd.read_csv(r'./consulados.csv')

# %%
# Visualizar las 5 primeras filas (df.head())

df_consulados.head()
# Out:
#    Unnamed: 0   register_id                                           name  \
# 0           0  ﻿96319101233   Consolat General de la República d'Eslovènia
# 1           1  ﻿99400505899                    Consolat Honorari de Belice
# 2           2  ﻿92086002925                     Consolat General de Mònaco
# 3           3  ﻿92086001095                  Consolat General de Dinamarca
# 4           4  ﻿99400012127  Consolat Honorari de la República de  Croàcia
#
#    institution_id institution_name      created     modified  \
# 0             NaN              NaN  35383.00000  44821.22658
# 1             NaN              NaN  42884.70389  44821.37527
# 2             NaN              NaN  30832.00000  44821.16143
# 3             NaN              NaN  30832.00000  44821.15768
# 4             NaN              NaN  37449.57642  44821.24835
#
#    addresses_road_id addresses_road_name  addresses_start_street_number  ...  \
# 0              28000         Via Augusta                            120  ...
# 1             144601         Av Diagonal                            469  ...
# 2             359200        Av Pedralbes                             55  ...
# 3              74506      Rbla Catalunya                             45  ...
# 4             349706    C Comte d'Urgell                            165  ...
#
#    values_id  values_attribute_id values_category  values_attribute_name  \
# 0     195135                20001        Telèfons                   Tel.
# 1     230136                20001        Telèfons                   Tel.
# 2     160289                20001        Telèfons                   Tel.
# 3     160439                20001        Telèfons                   Tel.
# 4     205118                20001        Telèfons                   Tel.
#
#   values_value  values_outstanding geo_epgs_25831_x  geo_epgs_25831_y  \
# 0    937273639           VERDADERO     4.287670e+16      4.583660e+15
# 1    934303044           VERDADERO     4.286750e+15      4.582750e+15
# 2    930107700           VERDADERO     4.259390e+14      4.582840e+16
# 3  934 880 222           VERDADERO     4.301260e+15      4.582430e+14
# 4    932720043           VERDADERO     4.290080e+15      4.582150e+15
#
#    geo_epgs_4326_x geo_epgs_4326_y
# 0     4.140130e+15    2.147820e+16
# 1     4.139310e+15    2.146830e+15
# 2     4.139370e+14    2.114100e+16
# 3     4.139040e+15    2.164220e+16
# 4     4.138780e+16    2.150880e+16
#
# [5 rows x 27 columns]

# %%
# Dimensiones del dataframe

df_consulados.shape
# Out:
# (92, 27)

# %% [markdown]
# **¿Mantiene los mismos campos el csv generado y el json facilitado con el enunciado?**

# %% [markdown]
# *Respuesta:* SI

# %%
#¿Con qué tipo de dato asocia pandas a cada columna del dataframe? (df.types)

df_consulados.dtypes
# Out:
# Unnamed: 0                         int64
# register_id                       object
# name                              object
# institution_id                   float64
# institution_name                  object
# created                          float64
# modified                         float64
# addresses_road_id                  int64
# addresses_road_name               object
# addresses_start_street_number      int64
# addresses_end_street_number      float64
# addresses_neighborhood_id          int64
# addresses_neighborhood_name       object
# addresses_district_id              int64
# addresses_district_name           object
# addresses_zip_code                 int64
# addresses_town                    object
# values_id                          int64
# values_attribute_id                int64
# values_category                   object
# values_attribute_name             object
# values_value                      object
# values_outstanding                object
# geo_epgs_25831_x                 float64
# geo_epgs_25831_y                 float64
# geo_epgs_4326_x                  float64
# geo_epgs_4326_y                  float64
# dtype: object

# %% [markdown]
# ---
#
# **ALTAS HOSPITALARIAS**

# %%
# Cargar el fichero y visualizarlo correctamente,

json_file_path = r'./altas_hospitalarias.json'
with open(json_file_path, 'r', encoding="utf8") as j:
     contents = json.load(j)

dict_altas = {'Nombre': [],
               'MetaData': [],
               'Data': []
               }

for element in contents:
     nombre = element['Nombre']
     metadata = element['MetaData'][2]['Nombre']
     data = element['Data'][0]['Valor']
     dict_altas['Nombre'].append(nombre)
     dict_altas['MetaData'].append(metadata)
     dict_altas['Data'].append(data)

# %% [markdown]
# **¿Cuántos registros tiene? ¿Que campos tiene cada registro? ¿de qué tipo son?**

# %% [markdown]
# _Respuesta:_
# - Tiene tres registros (Nombre, MetaData y Data), con un total de 984 campos
# - Nombre y MetaData son objects, mientras que Data es float64

# %%
# Transformar el json a un dataframe apoyándote en la librería pandas, según indicaciones

df_altas = pd.DataFrame(dict_altas)

df_altas
# Out:
#                                                 Nombre     MetaData  \
# 0    TODAS LAS CAUSAS A00-Z99 (salvo los códigos V,...  Ambos sexos
# 1    TODAS LAS CAUSAS A00-Z99 (salvo los códigos V,...      Hombres
# 2    TODAS LAS CAUSAS A00-Z99 (salvo los códigos V,...      Mujeres
# 3    TODAS LAS CAUSAS A00-Z99 (salvo los códigos V,...  Ambos sexos
# 4    TODAS LAS CAUSAS A00-Z99 (salvo los códigos V,...      Hombres
# ..                                                 ...          ...
# 889  ALTAS SIN DIAGNÓSTICO, Altas hospitalarias dur...      Hombres
# 890  ALTAS SIN DIAGNÓSTICO, Altas hospitalarias dur...      Mujeres
# 891  ALTAS SIN DIAGNÓSTICO, Estancias causadas, Amb...  Ambos sexos
# 892  ALTAS SIN DIAGNÓSTICO, Estancias causadas, Hom...      Hombres
# 893  ALTAS SIN DIAGNÓSTICO, Estancias causadas, Muj...      Mujeres
#
#            Data
# 0     4899954.0
# 1     2349175.0
# 2     2550779.0
# 3    40563057.0
# 4    21048584.0
# ..          ...
# 889      4204.0
# 890      4359.0
# 891    109834.0
# 892     55497.0
# 893     54337.0
#
# [894 rows x 3 columns]

# %%
# ¿Cuántas categorías distintas puede tener la variable relativa al sexo? ¿Cuáles son?

df_altas['MetaData'].value_counts()
# Out:
# Ambos sexos    298
# Hombres        298
# Mujeres        298
# Name: MetaData, dtype: int64

# %%
# obten tantos dataframes como número de categorías distintas de la variable relativa al sexo haya

sexo_dataframes = [tabla for sexo, tabla in df_altas.groupby('MetaData')]

for dataframe in sexo_dataframes:
    dataframe.drop(columns='MetaData', inplace=True)

df_altas_ambos, df_altas_hombres, df_altas_mujeres = sexo_dataframes

df_altas_ambos
# Out:
#                                                 Nombre        Data
# 0    TODAS LAS CAUSAS A00-Z99 (salvo los códigos V,...   4899954.0
# 3    TODAS LAS CAUSAS A00-Z99 (salvo los códigos V,...  40563057.0
# 6    0100 CIERTAS ENFERMEDADES INFECCIOSAS Y PARASI...    114629.0
# 9    0100 CIERTAS ENFERMEDADES INFECCIOSAS Y PARASI...   1173734.0
# 12   0101 Enfermedades infecciosas intestinales, ex...     16850.0
# ..                                                 ...         ...
# 879  2104 Otra atención médica (incluyendo sesiones...    417758.0
# 882  2105 Otros factores que influyen en el estado ...     72350.0
# 885  2105 Otros factores que influyen en el estado ...    305336.0
# 888  ALTAS SIN DIAGNÓSTICO, Altas hospitalarias dur...      8563.0
# 891  ALTAS SIN DIAGNÓSTICO, Estancias causadas, Amb...    109834.0
#
# [298 rows x 2 columns]

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# **En este ejercicio vamos a realizar la combinación de dos ficheros csv, `merdados_.csv` y `2021_padro.csv`, mediante la creación de un único diccionario que contenga las características de cada mercado junto con las características demográficas (número de mujeres, hombres y total) que tiene el barrio donde se encuentra el mercado.
# Teniendo en cuenta esta especificación:**
#
# -	**La columna mediante la cual se hará la asociación es 'addresses_neighborhood_name' para el dataset de los mercados y 'Nom_Barri' para el dataset del padrón.**
#
# -	**Las claves del diccionario resultante serán los identificadores de los merdados (es decir, el campo ‘register_id’.**
#
# -	**Ejemplo de una instancia del diccionario resultante:**

# %% [markdown]
# ```
# {'\ufeff92086009452':
#
#   {'register_id': '\ufeff92086009452',
#   'name': 'Mercat de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '33049',
#   'modified': '44768,41858',
#   ...
#   'padro': {'Dones': 5688, 'Homes': 5464, 'Total': 11152}
#   },
# …
#
# ```

# %% [markdown]
# **Por tanto, los pasos a realizar en este ejercicio son:**
#
# - **Cargar los csv y visualizar la forma y las columnas que tienen.**
#
# - **Crear un diccionario a partir del dataframe relativo a los mercados(dict_mercados). Las claves de este diccionario debe ser el campo ‘register_id’. Los valores del diccionario serán a su vez otro diccionario donde las claves sean el resto de campos y los valores el valor que adquiere cada campo en cada mercado.**
#
# - **Crear un diccionario a partir del dataframe relativo al padron (dict_padro). Las claves de este diccionario debe ser el campo ‘Nom_Barri’. Los valores del diccionario serán a su vez otro diccionario donde las claves sean [`Dones', 'Homes' y 'Total]` y los valores el valor calculado que adquiere cada campo.**
#
# - **Crear un diccionario que sea la combinación de los dos anteriores (dict_completo). Este diccionario debe crearse añadiendo un campo nuevo a la información relativa a cada mercado del diccionario dict_mercados. Este nuevo campo se llamará ‘padro_barri’ y su valor será la información relativa al padrón que se corresponde con su barrio. En los casos donde no exista valor de padrón, asignar el valor  de ‘NA’.**
#
# - **Visualizar el diccionario resultante. ¿Cuántos registros tiene? ¿Coincide este valor con el número de instancias del dataframe df_mercados?**
#
# - **Con el diccionario resultante, responder a las siguientes preguntas accediendo a los valores del diccionario que responden a las mismas:**
#  - **¿Cuántas mujeres hay en el barrio que está el mercado con register_id=92086009450**
#  - **¿En qué calle esta el mercado cuyo register_id=﻿92086009457?**
#
#
# - **Guardar el diccionario en un fichero con formato .json.**

# %% [markdown]
# NOTA: Para la construcción del diccionario dict_completo, se recomienda que se genere un bucle donde en cada iteración se evalúe cada mercado de dict_mercados y se consulte si hay información del padron para el barrio donde está ubicado. En caso afirmativo añadir los datos indicados, en caso contrario, añadir el valor ‘NA’ al campo padro.

# %%
# Cargar csv y visualitzar la forma y les columnes

df_padro = pd.read_csv('./2021_padro.csv')

df_padro.shape
# Out:
# (3066, 8)

# %%
# Crear un diccionario a partir del dataframe relativo al padron (dict_padro)

padro_df_reduced = df_padro[['Sexe', 'Nombre', 'Nom_Barri']]

padro_df_reduced.groupby(['Nom_Barri','Sexe']).sum()

dict_padro = dict()

for barri in padro_df_reduced['Nom_Barri']:
    if barri not in dict_padro.keys():
        dones = int(padro_df_reduced[(padro_df_reduced['Nom_Barri'] == barri) & (padro_df_reduced['Sexe'] == 'Dones')].sum()[1])
        homes = int(padro_df_reduced[(padro_df_reduced['Nom_Barri'] == barri) & (padro_df_reduced['Sexe'] == 'Homes')].sum()[1])
        dict_padro[barri] = {'Dones': dones, 'Homes': homes}

for barri in dict_padro:
    dict_padro[barri]['Total']=dict_padro[barri]['Dones']+dict_padro[barri]['Homes']
# Out:
# {'el Raval': {'Dones': 22466, 'Homes': 26222, 'Total': 48688},
#  'el Barri Gòtic': {'Dones': 8843, 'Homes': 14007, 'Total': 22850},
#  'la Barceloneta': {'Dones': 7647, 'Homes': 7478, 'Total': 15125},
#  'Sant Pere, Santa Caterina i la Ribera': {'Dones': 11431,
#   'Homes': 11578,
#   'Total': 23009},
#  'el Fort Pienc': {'Dones': 17443, 'Homes': 16002, 'Total': 33445},
#  'la Sagrada Família': {'Dones': 28118, 'Homes': 24046, 'Total': 52164},
#  "la Dreta de l'Eixample": {'Dones': 23431, 'Homes': 20657, 'Total': 44088},
#  "l'Antiga Esquerra de l'Eixample": {'Dones': 22685,
#   'Homes': 20361,
#   'Total': 43046},
#  "la Nova Esquerra de l'Eixample": {'Dones': 30843,
#   'Homes': 27063,
#   'Total': 57906},
#  'Sant Antoni': {'Dones': 20253, 'Homes': 18447, 'Total': 38700},
#  'el Poble Sec': {'Dones': 20429, 'Homes': 19775, 'Total': 40204},
#  'la Marina del Prat Vermell': {'Dones': 657, 'Homes': 699, 'Total': 1356},
#  'la Marina de Port': {'Dones': 16141, 'Homes': 14951, 'Total': 31092},
#  'la Font de la Guatlla': {'Dones': 5377, 'Homes': 4862, 'Total': 10239},
#  'Hostafrancs': {'Dones': 8378, 'Homes': 7724, 'Total': 16102},
#  'la Bordeta': {'Dones': 10169, 'Homes': 9282, 'Total': 19451},
#  'Sants - Badal': {'Dones': 13239, 'Homes': 11664, 'Total': 24903},
#  'Sants': {'Dones': 22600, 'Homes': 21079, 'Total': 43679},
#  'les Corts': {'Dones': 24686, 'Homes': 21257, 'Total': 45943},
#  'la Maternitat i Sant Ramon': {'Dones': 12722,
#   'Homes': 11103,
#   'Total': 23825},
#  'Pedralbes': {'Dones': 6306, 'Homes': 5502, 'Total': 11808},
#  'Vallvidrera, el Tibidabo i les Planes': {'Dones': 2405,
#   'Homes': 2355,
#   'Total': 4760},
#  'Sarrià': {'Dones': 13243, 'Homes': 11526, 'Total': 24769},
#  'les Tres Torres': {'Dones': 8712, 'Homes': 7644, 'Total': 16356},
#  'Sant Gervasi - la Bonanova': {'Dones': 14003,
#   'Homes': 11981,
#   'Total': 25984},
#  'Sant Gervasi - Galvany': {'Dones': 26036, 'Homes': 21310, 'Total': 47346},
#  'el Putxet i el Farró': {'Dones': 16254, 'Homes': 13732, 'Total': 29986},
#  'Vallcarca i els Penitents': {'Dones': 8719, 'Homes': 7606, 'Total': 16325},
#  'el Coll': {'Dones': 4098, 'Homes': 3590, 'Total': 7688},
#  'la Salut': {'Dones': 7212, 'Homes': 6243, 'Total': 13455},
#  'la Vila de Gràcia': {'Dones': 27388, 'Homes': 23068, 'Total': 50456},
#  "el Camp d'en Grassot i Gràcia Nova": {'Dones': 19121,
#   'Homes': 16231,
#   'Total': 35352},
#  'el Baix Guinardó': {'Dones': 13877, 'Homes': 11965, 'Total': 25842},
#  'Can Baró': {'Dones': 4919, 'Homes': 4401, 'Total': 9320},
#  'el Guinardó': {'Dones': 19865, 'Homes': 17460, 'Total': 37325},
#  "la Font d'en Fargues": {'Dones': 4978, 'Homes': 4527, 'Total': 9505},
#  'el Carmel': {'Dones': 17166, 'Homes': 15558, 'Total': 32724},
#  'la Teixonera': {'Dones': 6248, 'Homes': 5796, 'Total': 12044},
#  'Sant Genís dels Agudells': {'Dones': 3896, 'Homes': 3489, 'Total': 7385},
#  'Montbau': {'Dones': 2812, 'Homes': 2302, 'Total': 5114},
#  "la Vall d'Hebron": {'Dones': 3169, 'Homes': 2763, 'Total': 5932},
#  'la Clota': {'Dones': 335, 'Homes': 363, 'Total': 698},
#  'Horta': {'Dones': 14918, 'Homes': 13137, 'Total': 28055},
#  'Vilapicina i la Torre Llobeta': {'Dones': 13999,
#   'Homes': 11876,
#   'Total': 25875},
#  'Porta': {'Dones': 14731, 'Homes': 13065, 'Total': 27796},
#  'el Turó de la Peira': {'Dones': 8609, 'Homes': 7577, 'Total': 16186},
#  'Can Peguera': {'Dones': 1181, 'Homes': 1034, 'Total': 2215},
#  'la Guineueta': {'Dones': 8213, 'Homes': 7054, 'Total': 15267},
#  'Canyelles': {'Dones': 3584, 'Homes': 3229, 'Total': 6813},
#  'les Roquetes': {'Dones': 8576, 'Homes': 7987, 'Total': 16563},
#  'Verdun': {'Dones': 6880, 'Homes': 5985, 'Total': 12865},
#  'la Prosperitat': {'Dones': 14282, 'Homes': 12586, 'Total': 26868},
#  'la Trinitat Nova': {'Dones': 3966, 'Homes': 3662, 'Total': 7628},
#  'Torre Baró': {'Dones': 1462, 'Homes': 1461, 'Total': 2923},
#  'Ciutat Meridiana': {'Dones': 5688, 'Homes': 5464, 'Total': 11152},
#  'Vallbona': {'Dones': 716, 'Homes': 685, 'Total': 1401},
#  'la Trinitat Vella': {'Dones': 5162, 'Homes': 5351, 'Total': 10513},
#  'Baró de Viver': {'Dones': 1355, 'Homes': 1298, 'Total': 2653},
#  'el Bon Pastor': {'Dones': 6870, 'Homes': 6860, 'Total': 13730},
#  'Sant Andreu': {'Dones': 30727, 'Homes': 27498, 'Total': 58225},
#  'la Sagrera': {'Dones': 15723, 'Homes': 13845, 'Total': 29568},
#  'el Congrés i els Indians': {'Dones': 7746, 'Homes': 6803, 'Total': 14549},
#  'Navas': {'Dones': 11888, 'Homes': 10411, 'Total': 22299},
#  "el Camp de l'Arpa del Clot": {'Dones': 20621,
#   'Homes': 18217,
#   'Total': 38838},
#  'el Clot': {'Dones': 13956, 'Homes': 12803, 'Total': 26759},
#  'el Parc i la Llacuna del Poblenou': {'Dones': 8219,
#   'Homes': 7695,
#   'Total': 15914},
#  'la Vila Olímpica del Poblenou': {'Dones': 4780,
#   'Homes': 4615,
#   'Total': 9395},
#  'el Poblenou': {'Dones': 17675, 'Homes': 16736, 'Total': 34411},
#  'Diagonal Mar i el Front Marítim del Poblenou': {'Dones': 6938,
#   'Homes': 6598,
#   'Total': 13536},
#  'el Besòs i el Maresme': {'Dones': 12440, 'Homes': 13676, 'Total': 26116},
#  'Provençals del Poblenou': {'Dones': 11036, 'Homes': 10149, 'Total': 21185},
#  'Sant Martí de Provençals': {'Dones': 13958, 'Homes': 12271, 'Total': 26229},
#  'la Verneda i la Pau': {'Dones': 15160, 'Homes': 13638, 'Total': 28798}}

# %%
# Carregar csv mercados

df_mercados = pd.read_csv('./merdados_.csv', sep=';')

# %%
## Crear un diccionario a partir del dataframe relativo a los mercados(dict_mercados)

df_mercados.drop_duplicates(subset='register_id',inplace=True)
df_mercados.set_index('register_id', inplace=True)

dict_mercados = df_mercados.T.to_dict()
# Out:
# {'\ufeff92086009449': {'name': 'Mercat de La Concepció',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,38445',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 18505,
#   'addresses_road_name': "Carrer d'Aragó",
#   'addresses_start_street_number': 311,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 7,
#   'addresses_neighborhood_name': "la Dreta de l'Eixample",
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8009,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161780,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132314',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30537E+14',
#   'geo_epgs_25831_y': '4,583E+15',
#   'geo_epgs_4326_x': '4,13956E+15',
#   'geo_epgs_4326_y': '2,16907E+15'},
#  '\ufeff92086009450': {'name': 'Mercat de la Sagrada Família',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,48622',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 238400,
#   'addresses_road_name': 'Carrer de Padilla',
#   'addresses_start_street_number': 255,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 6,
#   'addresses_neighborhood_name': 'la Sagrada Família',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8013,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161781,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132324',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31213E+16',
#   'geo_epgs_25831_y': '4,58412E+15',
#   'geo_epgs_4326_x': '4,14057E+15',
#   'geo_epgs_4326_y': '2,17703E+15'},
#  '\ufeff92086009452': {'name': 'Mercat de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '33049',
#   'modified': '44768,41858',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349706,
#   'addresses_road_name': "Carrer del Comte d'Urgell",
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 10,
#   'addresses_neighborhood_name': 'Sant Antoni',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8011,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161783,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132300',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29907E+16',
#   'geo_epgs_25831_y': '4,58123E+15',
#   'geo_epgs_4326_x': '4,13796E+15',
#   'geo_epgs_4326_y': '2,16174E+15'},
#  '\ufeff92086009457': {'name': 'Mercat de Les Corts',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,38082',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 343903,
#   'addresses_road_name': 'Travessera de les Corts',
#   'addresses_start_street_number': 215,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 19,
#   'addresses_neighborhood_name': 'les Corts',
#   'addresses_district_id': 4,
#   'addresses_district_name': 'Les Corts',
#   'addresses_zip_code': 8028,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162504,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '667570336',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27241E+16',
#   'geo_epgs_25831_y': '4,58176E+15',
#   'geo_epgs_4326_x': '4,13841E+15',
#   'geo_epgs_4326_y': '2,1298E+16'},
#  '\ufeff92086009773': {'name': 'Mercat de la Llibertat',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44732,37875',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 179107,
#   'addresses_road_name': 'Plaça de la Llibertat',
#   'addresses_start_street_number': 27,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 31,
#   'addresses_neighborhood_name': 'la Vila de Gràcia',
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8012,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162390,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '933687946',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,2926E+15',
#   'geo_epgs_25831_y': '4,58348E+15',
#   'geo_epgs_4326_x': '4,13997E+15',
#   'geo_epgs_4326_y': '2,15375E+16'},
#  '\ufeff92086009781': {'name': 'Mercat de Montserrat',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48757',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 120807,
#   'addresses_road_name': 'Via Favència',
#   'addresses_start_street_number': 241,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 50,
#   'addresses_neighborhood_name': 'les Roquetes',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8042,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162008,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132341',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31403E+15',
#   'geo_epgs_25831_y': '4,58863E+15',
#   'geo_epgs_4326_x': '4,14463E+16',
#   'geo_epgs_4326_y': '2,17879E+16'},
#  '\ufeff92086009789': {'name': 'Mercat de Sant Martí',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,43696',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 270107,
#   'addresses_road_name': 'Carrer de Puigcerdà',
#   'addresses_start_street_number': 206,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 73,
#   'addresses_neighborhood_name': 'la Verneda i la Pau',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8020,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161886,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132297',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,33591E+15',
#   'geo_epgs_25831_y': '4,58554E+13',
#   'geo_epgs_4326_x': '4,14187E+15',
#   'geo_epgs_4326_y': '2,20532E+16'},
#  '\ufeff92086009790': {'name': 'Mercat del Besòs',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44818,36006',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 165601,
#   'addresses_road_name': 'C Jaume Huguet',
#   'addresses_start_street_number': 38,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 70,
#   'addresses_neighborhood_name': 'el Besòs i el Maresme',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8019,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161887,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132305',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,34411E+16',
#   'geo_epgs_25831_y': '4,58559E+15',
#   'geo_epgs_4326_x': '4,14192E+16',
#   'geo_epgs_4326_y': '2,21513E+16'},
#  '\ufeff92086009451': {'name': 'Mercat del Ninot',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,58065',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 191204,
#   'addresses_road_name': 'Carrer de Mallorca',
#   'addresses_start_street_number': 133,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 8,
#   'addresses_neighborhood_name': "l'Antiga Esquerra de l'Eixample",
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8036,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161782,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132322',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29303E+15',
#   'geo_epgs_25831_y': '4,58216E+15',
#   'geo_epgs_4326_x': '4,13879E+15',
#   'geo_epgs_4326_y': '2,15441E+16'},
#  '\ufeff92086009775': {'name': 'Mercat del Carmel',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,49168',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 185700,
#   'addresses_road_name': 'C Llobregós',
#   'addresses_start_street_number': 149,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 37,
#   'addresses_neighborhood_name': 'el Carmel',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8032,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162003,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132335',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29459E+16',
#   'geo_epgs_25831_y': '4,58614E+15',
#   'geo_epgs_4326_x': '4,14237E+15',
#   'geo_epgs_4326_y': '2,15581E+15'},
#  '\ufeff92086009783': {'name': 'Mercat de La Trinitat',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48686',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 250507,
#   'addresses_road_name': 'Carrer de la Pedrosa',
#   'addresses_start_street_number': 21,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 53,
#   'addresses_neighborhood_name': 'la Trinitat Nova',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8033,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162010,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132343',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3186E+15',
#   'geo_epgs_25831_y': '4,58889E+15',
#   'geo_epgs_4326_x': '4,14487E+15',
#   'geo_epgs_4326_y': '2,18423E+16'},
#  '\ufeff92086009785': {'name': 'Mercat de Felip II',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48279',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 121402,
#   'addresses_road_name': 'Carrer de Felip II',
#   'addresses_start_street_number': 118,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 61,
#   'addresses_neighborhood_name': 'la Sagrera',
#   'addresses_district_id': 9,
#   'addresses_district_name': 'Sant Andreu',
#   'addresses_zip_code': 8027,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162012,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132337',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31904E+16',
#   'geo_epgs_25831_y': '4,58593E+15',
#   'geo_epgs_4326_x': '4,1422E+15',
#   'geo_epgs_4326_y': '2,18509E+16'},
#  '\ufeff92086009459': {'name': 'Mercat de Sarrià',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,49005',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 278007,
#   'addresses_road_name': 'Pg Reina Elisenda Montcada',
#   'addresses_start_street_number': 8,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 23,
#   'addresses_neighborhood_name': 'Sarrià',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8034,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161787,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132326',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,265E+15',
#   'geo_epgs_25831_y': '4,58352E+15',
#   'geo_epgs_4326_x': '4,13998E+16',
#   'geo_epgs_4326_y': '2,12072E+16'},
#  '\ufeff92086009463': {'name': "Mercat de l'Abaceria Central",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,5772',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 305100,
#   'addresses_road_name': 'Pg Sant Joan',
#   'addresses_start_street_number': 181,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 32,
#   'addresses_neighborhood_name': "el Camp d'en Grassot i Gràcia Nova",
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8037,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161639,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132313',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30136E+16',
#   'geo_epgs_25831_y': '4,58385E+15',
#   'geo_epgs_4326_x': '4,14032E+16',
#   'geo_epgs_4326_y': '2,16418E+16'},
#  '\ufeff92086019717': {'name': 'Mercat de Canyelles',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31862',
#   'modified': '44728,48193',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 18254,
#   'addresses_road_name': "Carrer d'Antonio Machado",
#   'addresses_start_street_number': 10,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 49,
#   'addresses_neighborhood_name': 'Canyelles',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8042,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 166176,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132324',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30198E+15',
#   'geo_epgs_25831_y': '4,58816E+15',
#   'geo_epgs_4326_x': '4,1442E+15',
#   'geo_epgs_4326_y': '2,16443E+14'},
#  '\ufeff92086009782': {'name': 'Mercat de Ciutat Meridiana',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48264',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 92950,
#   'addresses_road_name': 'Carrer de Costabona',
#   'addresses_start_street_number': 4,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 55,
#   'addresses_neighborhood_name': 'Ciutat Meridiana',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8033,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162009,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132336',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31337E+15',
#   'geo_epgs_25831_y': '4,59034E+16',
#   'geo_epgs_4326_x': '4,14617E+15',
#   'geo_epgs_4326_y': '2,17781E+16'},
#  '\ufeff92086009787': {'name': 'Mercat de Sant Andreu',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44819,56347',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 208307,
#   'addresses_road_name': 'Plaça del Mercadal',
#   'addresses_start_street_number': 41,
#   'addresses_end_street_number': 41.0,
#   'addresses_neighborhood_id': 60,
#   'addresses_neighborhood_name': 'Sant Andreu',
#   'addresses_district_id': 9,
#   'addresses_district_name': 'Sant Andreu',
#   'addresses_zip_code': 8030,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162013,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132342',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '432192986',
#   'geo_epgs_25831_y': '4587353979',
#   'geo_epgs_4326_x': '4,14349E+15',
#   'geo_epgs_4326_y': '2,18839E+16'},
#  '\ufeff92086009458': {'name': 'Mercat de Galvany',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,48292',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 318804,
#   'addresses_road_name': 'Carrer de Santaló',
#   'addresses_start_street_number': 65,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 26,
#   'addresses_neighborhood_name': 'Sant Gervasi - Galvany',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8021,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161786,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132317',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28415E+16',
#   'geo_epgs_25831_y': '4,58315E+15',
#   'geo_epgs_4326_x': '4,13967E+15',
#   'geo_epgs_4326_y': '2,14368E+15'},
#  '\ufeff92086009460': {'name': 'Mercat de Les Tres Torres',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,48724',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 357103,
#   'addresses_road_name': 'Carrer dels Vergós',
#   'addresses_start_street_number': 2,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 24,
#   'addresses_neighborhood_name': 'les Tres Torres',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8017,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161788,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132327',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27382E+15',
#   'geo_epgs_25831_y': '4,58352E+15',
#   'geo_epgs_4326_x': '4,13999E+15',
#   'geo_epgs_4326_y': '2,13128E+15'},
#  '\ufeff92086009462': {'name': 'Mercat de Sant Gervasi',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,38267',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 231706,
#   'addresses_road_name': 'Pl Joaquim Folguera',
#   'addresses_start_street_number': 6,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 25,
#   'addresses_neighborhood_name': 'Sant Gervasi - la Bonanova',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8022,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161789,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132325',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27996E+15',
#   'geo_epgs_25831_y': '4,58415E+14',
#   'geo_epgs_4326_x': '4,14057E+15',
#   'geo_epgs_4326_y': '2,13855E+15'},
#  '\ufeff92086009468': {'name': 'Mercat Encants Vells Fira de Bellcaire',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,57901',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 73900,
#   'addresses_road_name': 'Carrer de los Castillejos',
#   'addresses_start_street_number': 158,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 5,
#   'addresses_neighborhood_name': 'el Fort Pienc',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8013,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161792,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132328',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3193E+15',
#   'geo_epgs_25831_y': '4,5836E+15',
#   'geo_epgs_4326_x': '4,14011E+16',
#   'geo_epgs_4326_y': '2,18567E+16'},
#  '\ufeff92086009464': {'name': 'Mercat de Lesseps',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,37627',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 356803,
#   'addresses_road_name': 'Carrer de Verdi',
#   'addresses_start_street_number': 200,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 30,
#   'addresses_neighborhood_name': 'la Salut',
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8024,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161790,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132319',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29129E+15',
#   'geo_epgs_25831_y': '4,58452E+15',
#   'geo_epgs_4326_x': '4,14091E+15',
#   'geo_epgs_4326_y': '2,15206E+16'},
#  '\ufeff92086009467': {'name': 'Mercat Encants de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44770,57452',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349706,
#   'addresses_road_name': "C Comte d'Urgell",
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 10,
#   'addresses_neighborhood_name': 'Sant Antoni',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8011,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161791,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132300',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30052E+15',
#   'geo_epgs_25831_y': '4,58142E+15',
#   'geo_epgs_4326_x': '4,13813E+15',
#   'geo_epgs_4326_y': '2,16345E+16'},
#  '\ufeff92086009447': {'name': 'Mercat de Sant Josep - La Boqueria',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,57829',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 34308,
#   'addresses_road_name': 'Carrer la Rambla',
#   'addresses_start_street_number': 89,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 1,
#   'addresses_neighborhood_name': 'el Raval',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8002,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161741,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132303',
#   'values_outstanding': 'VERDADERO',
#   'values_description': 'Informació',
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3079E+15',
#   'geo_epgs_25831_y': '4,5815E+15',
#   'geo_epgs_4326_x': '4,1382E+16',
#   'geo_epgs_4326_y': '2,17227E+16'},
#  '\ufeff92086009448': {'name': 'Mercat de Santa Caterina',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,58194',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 132952,
#   'addresses_road_name': 'Av Francesc Cambó',
#   'addresses_start_street_number': 16,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 4,
#   'addresses_neighborhood_name': 'Sant Pere, Santa Caterina i la Ribera',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8003,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161718,
#   'values_attribute_id': 20006,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Informació',
#   'values_value': '934132298',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31288E+16',
#   'geo_epgs_25831_y': '4,58198E+16',
#   'geo_epgs_4326_x': '4,13864E+15',
#   'geo_epgs_4326_y': '2,17818E+16'},
#  '\ufeff92086009454': {'name': "Mercat d'Hostafrancs",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,4821',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 94809,
#   'addresses_road_name': 'Carrer de la Creu Coberta',
#   'addresses_start_street_number': 93,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 15,
#   'addresses_neighborhood_name': 'Hostafrancs',
#   'addresses_district_id': 3,
#   'addresses_district_name': 'Sants-Montjuïc',
#   'addresses_zip_code': 8014,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161784,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132307',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28406E+15',
#   'geo_epgs_25831_y': '4,58076E+15',
#   'geo_epgs_4326_x': '4,13752E+15',
#   'geo_epgs_4326_y': '2,14385E+15'},
#  '\ufeff92086009455': {'name': 'Mercat de Sants',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44768,41922',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 304209,
#   'addresses_road_name': 'C Sant Jordi',
#   'addresses_start_street_number': 6,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 18,
#   'addresses_neighborhood_name': 'Sants',
#   'addresses_district_id': 3,
#   'addresses_district_name': 'Sants-Montjuïc',
#   'addresses_zip_code': 8028,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162421,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '932694472',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27561E+16',
#   'geo_epgs_25831_y': '4,58072E+15',
#   'geo_epgs_4326_x': '4,13747E+15',
#   'geo_epgs_4326_y': '2,13375E+16'},
#  '\ufeff92086009456': {'name': 'Mercat de La Marina',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,39465',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 369408,
#   'addresses_road_name': 'Passeig de la Zona Franca',
#   'addresses_start_street_number': 178,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 13,
#   'addresses_neighborhood_name': 'la Marina de Port',
#   'addresses_district_id': 3,
#   'addresses_district_name': 'Sants-Montjuïc',
#   'addresses_zip_code': 8038,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161785,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132308',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28E+15',
#   'geo_epgs_25831_y': '4,57912E+15',
#   'geo_epgs_4326_x': '4,13604E+15',
#   'geo_epgs_4326_y': '2,13919E+16'},
#  '\ufeff92086011624': {'name': 'Mercat de les Flors *Les Rambles',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31128',
#   'modified': '44727,41879',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 34308,
#   'addresses_road_name': 'C la Rambla',
#   'addresses_start_street_number': 116,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 2,
#   'addresses_neighborhood_name': 'el Barri Gòtic',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8002,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 163447,
#   'values_attribute_id': 100050,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'No tenen telèfon',
#   'values_value': '-',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30764E+16',
#   'geo_epgs_25831_y': '4,5816E+13',
#   'geo_epgs_4326_x': '4,1383E+15',
#   'geo_epgs_4326_y': '2,17195E+16'},
#  '\ufeff96058202955': {'name': 'Mercat Dominical de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '35122',
#   'modified': '44755,4564',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349706,
#   'addresses_road_name': "C Comte d'Urgell",
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 10,
#   'addresses_neighborhood_name': 'Sant Antoni',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8011,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 189742,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132300',
#   'values_outstanding': 'VERDADERO',
#   'values_description': 'Mercat de Sant Antoni',
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29907E+16',
#   'geo_epgs_25831_y': '4,58123E+15',
#   'geo_epgs_4326_x': '4,13796E+15',
#   'geo_epgs_4326_y': '2,16174E+15'},
#  '\ufeff92086009445': {'name': 'Mercat de La Barceloneta',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44825,41282',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 260908,
#   'addresses_road_name': 'Plaça del Poeta Boscà',
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 3,
#   'addresses_neighborhood_name': 'la Barceloneta',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8003,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162818,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132304',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3221E+16',
#   'geo_epgs_25831_y': '4,58129E+15',
#   'geo_epgs_4326_x': '4,13802E+15',
#   'geo_epgs_4326_y': '2,18928E+14'},
#  '\ufeff92086009776': {'name': 'Mercat del Guinardó',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,42299',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 334403,
#   'addresses_road_name': 'C Teodor Llorente',
#   'addresses_start_street_number': 10,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 35,
#   'addresses_neighborhood_name': 'el Guinardó',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8041,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162004,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132332',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31452E+15',
#   'geo_epgs_25831_y': '4,58561E+15',
#   'geo_epgs_4326_x': '4,14192E+16',
#   'geo_epgs_4326_y': '2,17972E+15'},
#  '\ufeff92086009779': {'name': 'Mercat de La Guineueta',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44776,56573',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 351901,
#   'addresses_road_name': 'Passeig de Valldaura',
#   'addresses_start_street_number': 186,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 48,
#   'addresses_neighborhood_name': 'la Guineueta',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8042,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162006,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132338',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30681E+15',
#   'geo_epgs_25831_y': '4,58779E+15',
#   'geo_epgs_4326_x': '4,14387E+15',
#   'geo_epgs_4326_y': '2,17025E+15'},
#  '\ufeff92086009788': {'name': 'Mercat del Clot',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,4115',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 209004,
#   'addresses_road_name': 'Pl Mercat',
#   'addresses_start_street_number': 26,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 65,
#   'addresses_neighborhood_name': 'el Clot',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8018,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162417,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132306',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,32186E+15',
#   'geo_epgs_25831_y': '4,58433E+14',
#   'geo_epgs_4326_x': '4,14076E+15',
#   'geo_epgs_4326_y': '2,18864E+16'},
#  '\ufeff92086009791': {'name': 'Mercat del Poblenou',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,49295',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349003,
#   'addresses_road_name': 'Pl Unió',
#   'addresses_start_street_number': 25,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 68,
#   'addresses_neighborhood_name': 'el Poblenou',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8005,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161888,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132309',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,33582E+16',
#   'geo_epgs_25831_y': '4,58358E+15',
#   'geo_epgs_4326_x': '4,1401E+15',
#   'geo_epgs_4326_y': '2,20543E+16'},
#  '\ufeff92086009793': {'name': 'Mercat de Provençals',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,43597',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 208205,
#   'addresses_road_name': 'Carrer de Menorca',
#   'addresses_start_street_number': 19,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 72,
#   'addresses_neighborhood_name': 'Sant Martí de Provençals',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8020,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162487,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '662002663',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,32853E+15',
#   'geo_epgs_25831_y': '4,58563E+15',
#   'geo_epgs_4326_x': '4,14195E+15',
#   'geo_epgs_4326_y': '2,19649E+16'},
#  '\ufeff92086009774': {'name': "Mercat de l'Estrella",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44753,5782',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 144306,
#   'addresses_road_name': 'Carrer de Pi i Margall',
#   'addresses_start_street_number': 73,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 32,
#   'addresses_neighborhood_name': "el Camp d'en Grassot i Gràcia Nova",
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8024,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162002,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132315',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30128E+15',
#   'geo_epgs_25831_y': '4,5846E+15',
#   'geo_epgs_4326_x': '4,14099E+16',
#   'geo_epgs_4326_y': '2,16399E+16'},
#  '\ufeff92086009777': {'name': "Mercat de Vall d'Hebron -Taxonera",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44824,42722',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 352507,
#   'addresses_road_name': "Pg Vall d'Hebron",
#   'addresses_start_street_number': 130,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 38,
#   'addresses_neighborhood_name': 'la Teixonera',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8035,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162005,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132344',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28343E+16',
#   'geo_epgs_25831_y': '4,58619E+15',
#   'geo_epgs_4326_x': '4,14241E+15',
#   'geo_epgs_4326_y': '2,14245E+15'},
#  '\ufeff92086009778': {'name': "Mercat d'Horta",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44824,42873',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 329505,
#   'addresses_road_name': 'Carrer del Tajo',
#   'addresses_start_street_number': 75,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 43,
#   'addresses_neighborhood_name': 'Horta',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8032,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162391,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '934204858',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29782E+15',
#   'geo_epgs_25831_y': '4,58679E+13',
#   'geo_epgs_4326_x': '4,14296E+15',
#   'geo_epgs_4326_y': '2,15961E+16'},
#  '\ufeff92086009780': {'name': 'Mercat de La Mercè',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44771,46113',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 119003,
#   'addresses_road_name': 'Passeig de Fabra i Puig',
#   'addresses_start_street_number': 270,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 46,
#   'addresses_neighborhood_name': 'el Turó de la Peira',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8031,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162007,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132340',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30952E+15',
#   'geo_epgs_25831_y': '4,58688E+15',
#   'geo_epgs_4326_x': '4,14305E+16',
#   'geo_epgs_4326_y': '2,1736E+16'},
#  '\ufeff92086009784': {'name': 'Mercat del Bon Pastor',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,49155',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 295709,
#   'addresses_road_name': 'C Sant Adrià',
#   'addresses_start_street_number': 154,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 59,
#   'addresses_neighborhood_name': 'el Bon Pastor',
#   'addresses_district_id': 9,
#   'addresses_district_name': 'Sant Andreu',
#   'addresses_zip_code': 8030,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162011,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132333',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,33679E+15',
#   'geo_epgs_25831_y': '4,58746E+15',
#   'geo_epgs_4326_x': '4,1436E+15',
#   'geo_epgs_4326_y': '2,20617E+15'},
#  '\ufeff99400069155': {'name': 'Mercat del Fort Pienc',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '37958,58828',
#   'modified': '44732,38674',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 701420,
#   'addresses_road_name': 'Pl Fort Pienc',
#   'addresses_start_street_number': 3,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 5,
#   'addresses_neighborhood_name': 'el Fort Pienc',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8013,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 208673,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132316',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31663E+15',
#   'geo_epgs_25831_y': '4,58302E+15',
#   'geo_epgs_4326_x': '4,13958E+15',
#   'geo_epgs_4326_y': '2,18254E+15'},
#  '\ufeff99400695137': {'name': 'Mercat de Núria',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '44754,5899',
#   'modified': '44760,37418',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 275600,
#   'addresses_road_name': 'Avinguda dels Rasos de Peguera',
#   'addresses_start_street_number': 186,
#   'addresses_end_street_number': 186.0,
#   'addresses_neighborhood_id': 55,
#   'addresses_neighborhood_name': 'Ciutat Meridiana',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8033,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 460429,
#   'values_attribute_id': 20006,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Informació',
#   'values_value': '934132890',
#   'values_outstanding': 'FALSO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '430903145',
#   'geo_epgs_25831_y': '4590148469',
#   'geo_epgs_4326_x': '4,146E+15',
#   'geo_epgs_4326_y': '2,17264E+16'}}

# %%
# Crear dict completo
for k,v in dict_mercados.items():
  if v['addresses_neighborhood_name'] in dict_padro.keys():
    dict_mercados[k]['padro'] = dict_padro[v['addresses_neighborhood_name']]
  else:
    dict_mercados[k]['padro']['Oficina']='NA'
# Out:
# {'\ufeff92086009449': {'name': 'Mercat de La Concepció',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,38445',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 18505,
#   'addresses_road_name': "Carrer d'Aragó",
#   'addresses_start_street_number': 311,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 7,
#   'addresses_neighborhood_name': "la Dreta de l'Eixample",
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8009,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161780,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132314',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30537E+14',
#   'geo_epgs_25831_y': '4,583E+15',
#   'geo_epgs_4326_x': '4,13956E+15',
#   'geo_epgs_4326_y': '2,16907E+15',
#   'padro': {'Dones': 23431, 'Homes': 20657, 'Total': 44088}},
#  '\ufeff92086009450': {'name': 'Mercat de la Sagrada Família',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,48622',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 238400,
#   'addresses_road_name': 'Carrer de Padilla',
#   'addresses_start_street_number': 255,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 6,
#   'addresses_neighborhood_name': 'la Sagrada Família',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8013,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161781,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132324',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31213E+16',
#   'geo_epgs_25831_y': '4,58412E+15',
#   'geo_epgs_4326_x': '4,14057E+15',
#   'geo_epgs_4326_y': '2,17703E+15',
#   'padro': {'Dones': 28118, 'Homes': 24046, 'Total': 52164}},
#  '\ufeff92086009452': {'name': 'Mercat de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '33049',
#   'modified': '44768,41858',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349706,
#   'addresses_road_name': "Carrer del Comte d'Urgell",
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 10,
#   'addresses_neighborhood_name': 'Sant Antoni',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8011,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161783,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132300',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29907E+16',
#   'geo_epgs_25831_y': '4,58123E+15',
#   'geo_epgs_4326_x': '4,13796E+15',
#   'geo_epgs_4326_y': '2,16174E+15',
#   'padro': {'Dones': 20253, 'Homes': 18447, 'Total': 38700}},
#  '\ufeff92086009457': {'name': 'Mercat de Les Corts',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,38082',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 343903,
#   'addresses_road_name': 'Travessera de les Corts',
#   'addresses_start_street_number': 215,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 19,
#   'addresses_neighborhood_name': 'les Corts',
#   'addresses_district_id': 4,
#   'addresses_district_name': 'Les Corts',
#   'addresses_zip_code': 8028,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162504,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '667570336',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27241E+16',
#   'geo_epgs_25831_y': '4,58176E+15',
#   'geo_epgs_4326_x': '4,13841E+15',
#   'geo_epgs_4326_y': '2,1298E+16',
#   'padro': {'Dones': 24686, 'Homes': 21257, 'Total': 45943}},
#  '\ufeff92086009773': {'name': 'Mercat de la Llibertat',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44732,37875',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 179107,
#   'addresses_road_name': 'Plaça de la Llibertat',
#   'addresses_start_street_number': 27,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 31,
#   'addresses_neighborhood_name': 'la Vila de Gràcia',
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8012,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162390,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '933687946',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,2926E+15',
#   'geo_epgs_25831_y': '4,58348E+15',
#   'geo_epgs_4326_x': '4,13997E+15',
#   'geo_epgs_4326_y': '2,15375E+16',
#   'padro': {'Dones': 27388, 'Homes': 23068, 'Total': 50456}},
#  '\ufeff92086009781': {'name': 'Mercat de Montserrat',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48757',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 120807,
#   'addresses_road_name': 'Via Favència',
#   'addresses_start_street_number': 241,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 50,
#   'addresses_neighborhood_name': 'les Roquetes',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8042,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162008,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132341',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31403E+15',
#   'geo_epgs_25831_y': '4,58863E+15',
#   'geo_epgs_4326_x': '4,14463E+16',
#   'geo_epgs_4326_y': '2,17879E+16',
#   'padro': {'Dones': 8576, 'Homes': 7987, 'Total': 16563}},
#  '\ufeff92086009789': {'name': 'Mercat de Sant Martí',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,43696',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 270107,
#   'addresses_road_name': 'Carrer de Puigcerdà',
#   'addresses_start_street_number': 206,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 73,
#   'addresses_neighborhood_name': 'la Verneda i la Pau',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8020,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161886,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132297',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,33591E+15',
#   'geo_epgs_25831_y': '4,58554E+13',
#   'geo_epgs_4326_x': '4,14187E+15',
#   'geo_epgs_4326_y': '2,20532E+16',
#   'padro': {'Dones': 15160, 'Homes': 13638, 'Total': 28798}},
#  '\ufeff92086009790': {'name': 'Mercat del Besòs',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44818,36006',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 165601,
#   'addresses_road_name': 'C Jaume Huguet',
#   'addresses_start_street_number': 38,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 70,
#   'addresses_neighborhood_name': 'el Besòs i el Maresme',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8019,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161887,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132305',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,34411E+16',
#   'geo_epgs_25831_y': '4,58559E+15',
#   'geo_epgs_4326_x': '4,14192E+16',
#   'geo_epgs_4326_y': '2,21513E+16',
#   'padro': {'Dones': 12440, 'Homes': 13676, 'Total': 26116}},
#  '\ufeff92086009451': {'name': 'Mercat del Ninot',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,58065',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 191204,
#   'addresses_road_name': 'Carrer de Mallorca',
#   'addresses_start_street_number': 133,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 8,
#   'addresses_neighborhood_name': "l'Antiga Esquerra de l'Eixample",
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8036,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161782,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132322',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29303E+15',
#   'geo_epgs_25831_y': '4,58216E+15',
#   'geo_epgs_4326_x': '4,13879E+15',
#   'geo_epgs_4326_y': '2,15441E+16',
#   'padro': {'Dones': 22685, 'Homes': 20361, 'Total': 43046}},
#  '\ufeff92086009775': {'name': 'Mercat del Carmel',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,49168',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 185700,
#   'addresses_road_name': 'C Llobregós',
#   'addresses_start_street_number': 149,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 37,
#   'addresses_neighborhood_name': 'el Carmel',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8032,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162003,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132335',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29459E+16',
#   'geo_epgs_25831_y': '4,58614E+15',
#   'geo_epgs_4326_x': '4,14237E+15',
#   'geo_epgs_4326_y': '2,15581E+15',
#   'padro': {'Dones': 17166, 'Homes': 15558, 'Total': 32724}},
#  '\ufeff92086009783': {'name': 'Mercat de La Trinitat',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48686',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 250507,
#   'addresses_road_name': 'Carrer de la Pedrosa',
#   'addresses_start_street_number': 21,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 53,
#   'addresses_neighborhood_name': 'la Trinitat Nova',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8033,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162010,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132343',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3186E+15',
#   'geo_epgs_25831_y': '4,58889E+15',
#   'geo_epgs_4326_x': '4,14487E+15',
#   'geo_epgs_4326_y': '2,18423E+16',
#   'padro': {'Dones': 3966, 'Homes': 3662, 'Total': 7628}},
#  '\ufeff92086009785': {'name': 'Mercat de Felip II',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48279',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 121402,
#   'addresses_road_name': 'Carrer de Felip II',
#   'addresses_start_street_number': 118,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 61,
#   'addresses_neighborhood_name': 'la Sagrera',
#   'addresses_district_id': 9,
#   'addresses_district_name': 'Sant Andreu',
#   'addresses_zip_code': 8027,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162012,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132337',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31904E+16',
#   'geo_epgs_25831_y': '4,58593E+15',
#   'geo_epgs_4326_x': '4,1422E+15',
#   'geo_epgs_4326_y': '2,18509E+16',
#   'padro': {'Dones': 15723, 'Homes': 13845, 'Total': 29568}},
#  '\ufeff92086009459': {'name': 'Mercat de Sarrià',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,49005',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 278007,
#   'addresses_road_name': 'Pg Reina Elisenda Montcada',
#   'addresses_start_street_number': 8,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 23,
#   'addresses_neighborhood_name': 'Sarrià',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8034,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161787,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132326',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 66731068,
#   'secondary_filters_name': 'WiFi BCN',
#   'secondary_filters_fullpath': "Planol BCN >> Internet >> Punts d'accés a Internet >> WiFi BCN",
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,265E+15',
#   'geo_epgs_25831_y': '4,58352E+15',
#   'geo_epgs_4326_x': '4,13998E+16',
#   'geo_epgs_4326_y': '2,12072E+16',
#   'padro': {'Dones': 13243, 'Homes': 11526, 'Total': 24769}},
#  '\ufeff92086009463': {'name': "Mercat de l'Abaceria Central",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,5772',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 305100,
#   'addresses_road_name': 'Pg Sant Joan',
#   'addresses_start_street_number': 181,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 32,
#   'addresses_neighborhood_name': "el Camp d'en Grassot i Gràcia Nova",
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8037,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161639,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132313',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30136E+16',
#   'geo_epgs_25831_y': '4,58385E+15',
#   'geo_epgs_4326_x': '4,14032E+16',
#   'geo_epgs_4326_y': '2,16418E+16',
#   'padro': {'Dones': 19121, 'Homes': 16231, 'Total': 35352}},
#  '\ufeff92086019717': {'name': 'Mercat de Canyelles',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31862',
#   'modified': '44728,48193',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 18254,
#   'addresses_road_name': "Carrer d'Antonio Machado",
#   'addresses_start_street_number': 10,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 49,
#   'addresses_neighborhood_name': 'Canyelles',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8042,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 166176,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132324',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30198E+15',
#   'geo_epgs_25831_y': '4,58816E+15',
#   'geo_epgs_4326_x': '4,1442E+15',
#   'geo_epgs_4326_y': '2,16443E+14',
#   'padro': {'Dones': 3584, 'Homes': 3229, 'Total': 6813}},
#  '\ufeff92086009782': {'name': 'Mercat de Ciutat Meridiana',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,48264',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 92950,
#   'addresses_road_name': 'Carrer de Costabona',
#   'addresses_start_street_number': 4,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 55,
#   'addresses_neighborhood_name': 'Ciutat Meridiana',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8033,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162009,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132336',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31337E+15',
#   'geo_epgs_25831_y': '4,59034E+16',
#   'geo_epgs_4326_x': '4,14617E+15',
#   'geo_epgs_4326_y': '2,17781E+16',
#   'padro': {'Dones': 5688, 'Homes': 5464, 'Total': 11152}},
#  '\ufeff92086009787': {'name': 'Mercat de Sant Andreu',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44819,56347',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 208307,
#   'addresses_road_name': 'Plaça del Mercadal',
#   'addresses_start_street_number': 41,
#   'addresses_end_street_number': 41.0,
#   'addresses_neighborhood_id': 60,
#   'addresses_neighborhood_name': 'Sant Andreu',
#   'addresses_district_id': 9,
#   'addresses_district_name': 'Sant Andreu',
#   'addresses_zip_code': 8030,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162013,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132342',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '432192986',
#   'geo_epgs_25831_y': '4587353979',
#   'geo_epgs_4326_x': '4,14349E+15',
#   'geo_epgs_4326_y': '2,18839E+16',
#   'padro': {'Dones': 30727, 'Homes': 27498, 'Total': 58225}},
#  '\ufeff92086009458': {'name': 'Mercat de Galvany',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,48292',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 318804,
#   'addresses_road_name': 'Carrer de Santaló',
#   'addresses_start_street_number': 65,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 26,
#   'addresses_neighborhood_name': 'Sant Gervasi - Galvany',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8021,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161786,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132317',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28415E+16',
#   'geo_epgs_25831_y': '4,58315E+15',
#   'geo_epgs_4326_x': '4,13967E+15',
#   'geo_epgs_4326_y': '2,14368E+15',
#   'padro': {'Dones': 26036, 'Homes': 21310, 'Total': 47346}},
#  '\ufeff92086009460': {'name': 'Mercat de Les Tres Torres',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,48724',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 357103,
#   'addresses_road_name': 'Carrer dels Vergós',
#   'addresses_start_street_number': 2,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 24,
#   'addresses_neighborhood_name': 'les Tres Torres',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8017,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161788,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132327',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27382E+15',
#   'geo_epgs_25831_y': '4,58352E+15',
#   'geo_epgs_4326_x': '4,13999E+15',
#   'geo_epgs_4326_y': '2,13128E+15',
#   'padro': {'Dones': 8712, 'Homes': 7644, 'Total': 16356}},
#  '\ufeff92086009462': {'name': 'Mercat de Sant Gervasi',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,38267',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 231706,
#   'addresses_road_name': 'Pl Joaquim Folguera',
#   'addresses_start_street_number': 6,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 25,
#   'addresses_neighborhood_name': 'Sant Gervasi - la Bonanova',
#   'addresses_district_id': 5,
#   'addresses_district_name': 'Sarrià-Sant Gervasi',
#   'addresses_zip_code': 8022,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161789,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132325',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27996E+15',
#   'geo_epgs_25831_y': '4,58415E+14',
#   'geo_epgs_4326_x': '4,14057E+15',
#   'geo_epgs_4326_y': '2,13855E+15',
#   'padro': {'Dones': 14003, 'Homes': 11981, 'Total': 25984}},
#  '\ufeff92086009468': {'name': 'Mercat Encants Vells Fira de Bellcaire',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,57901',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 73900,
#   'addresses_road_name': 'Carrer de los Castillejos',
#   'addresses_start_street_number': 158,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 5,
#   'addresses_neighborhood_name': 'el Fort Pienc',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8013,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161792,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132328',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3193E+15',
#   'geo_epgs_25831_y': '4,5836E+15',
#   'geo_epgs_4326_x': '4,14011E+16',
#   'geo_epgs_4326_y': '2,18567E+16',
#   'padro': {'Dones': 17443, 'Homes': 16002, 'Total': 33445}},
#  '\ufeff92086009464': {'name': 'Mercat de Lesseps',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,37627',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 356803,
#   'addresses_road_name': 'Carrer de Verdi',
#   'addresses_start_street_number': 200,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 30,
#   'addresses_neighborhood_name': 'la Salut',
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8024,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161790,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132319',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29129E+15',
#   'geo_epgs_25831_y': '4,58452E+15',
#   'geo_epgs_4326_x': '4,14091E+15',
#   'geo_epgs_4326_y': '2,15206E+16',
#   'padro': {'Dones': 7212, 'Homes': 6243, 'Total': 13455}},
#  '\ufeff92086009467': {'name': 'Mercat Encants de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44770,57452',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349706,
#   'addresses_road_name': "C Comte d'Urgell",
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 10,
#   'addresses_neighborhood_name': 'Sant Antoni',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8011,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161791,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132300',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30052E+15',
#   'geo_epgs_25831_y': '4,58142E+15',
#   'geo_epgs_4326_x': '4,13813E+15',
#   'geo_epgs_4326_y': '2,16345E+16',
#   'padro': {'Dones': 20253, 'Homes': 18447, 'Total': 38700}},
#  '\ufeff92086009447': {'name': 'Mercat de Sant Josep - La Boqueria',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,57829',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 34308,
#   'addresses_road_name': 'Carrer la Rambla',
#   'addresses_start_street_number': 89,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 1,
#   'addresses_neighborhood_name': 'el Raval',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8002,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161741,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132303',
#   'values_outstanding': 'VERDADERO',
#   'values_description': 'Informació',
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3079E+15',
#   'geo_epgs_25831_y': '4,5815E+15',
#   'geo_epgs_4326_x': '4,1382E+16',
#   'geo_epgs_4326_y': '2,17227E+16',
#   'padro': {'Dones': 22466, 'Homes': 26222, 'Total': 48688}},
#  '\ufeff92086009448': {'name': 'Mercat de Santa Caterina',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44757,58194',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 132952,
#   'addresses_road_name': 'Av Francesc Cambó',
#   'addresses_start_street_number': 16,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 4,
#   'addresses_neighborhood_name': 'Sant Pere, Santa Caterina i la Ribera',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8003,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161718,
#   'values_attribute_id': 20006,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Informació',
#   'values_value': '934132298',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31288E+16',
#   'geo_epgs_25831_y': '4,58198E+16',
#   'geo_epgs_4326_x': '4,13864E+15',
#   'geo_epgs_4326_y': '2,17818E+16',
#   'padro': {'Dones': 11431, 'Homes': 11578, 'Total': 23009}},
#  '\ufeff92086009454': {'name': "Mercat d'Hostafrancs",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44728,4821',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 94809,
#   'addresses_road_name': 'Carrer de la Creu Coberta',
#   'addresses_start_street_number': 93,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 15,
#   'addresses_neighborhood_name': 'Hostafrancs',
#   'addresses_district_id': 3,
#   'addresses_district_name': 'Sants-Montjuïc',
#   'addresses_zip_code': 8014,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161784,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132307',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28406E+15',
#   'geo_epgs_25831_y': '4,58076E+15',
#   'geo_epgs_4326_x': '4,13752E+15',
#   'geo_epgs_4326_y': '2,14385E+15',
#   'padro': {'Dones': 8378, 'Homes': 7724, 'Total': 16102}},
#  '\ufeff92086009455': {'name': 'Mercat de Sants',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44768,41922',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 304209,
#   'addresses_road_name': 'C Sant Jordi',
#   'addresses_start_street_number': 6,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 18,
#   'addresses_neighborhood_name': 'Sants',
#   'addresses_district_id': 3,
#   'addresses_district_name': 'Sants-Montjuïc',
#   'addresses_zip_code': 8028,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162421,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '932694472',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,27561E+16',
#   'geo_epgs_25831_y': '4,58072E+15',
#   'geo_epgs_4326_x': '4,13747E+15',
#   'geo_epgs_4326_y': '2,13375E+16',
#   'padro': {'Dones': 22600, 'Homes': 21079, 'Total': 43679}},
#  '\ufeff92086009456': {'name': 'Mercat de La Marina',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44732,39465',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 369408,
#   'addresses_road_name': 'Passeig de la Zona Franca',
#   'addresses_start_street_number': 178,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 13,
#   'addresses_neighborhood_name': 'la Marina de Port',
#   'addresses_district_id': 3,
#   'addresses_district_name': 'Sants-Montjuïc',
#   'addresses_zip_code': 8038,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161785,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132308',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28E+15',
#   'geo_epgs_25831_y': '4,57912E+15',
#   'geo_epgs_4326_x': '4,13604E+15',
#   'geo_epgs_4326_y': '2,13919E+16',
#   'padro': {'Dones': 16141, 'Homes': 14951, 'Total': 31092}},
#  '\ufeff92086011624': {'name': 'Mercat de les Flors *Les Rambles',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31128',
#   'modified': '44727,41879',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 34308,
#   'addresses_road_name': 'C la Rambla',
#   'addresses_start_street_number': 116,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 2,
#   'addresses_neighborhood_name': 'el Barri Gòtic',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8002,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 163447,
#   'values_attribute_id': 100050,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'No tenen telèfon',
#   'values_value': '-',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30764E+16',
#   'geo_epgs_25831_y': '4,5816E+13',
#   'geo_epgs_4326_x': '4,1383E+15',
#   'geo_epgs_4326_y': '2,17195E+16',
#   'padro': {'Dones': 8843, 'Homes': 14007, 'Total': 22850}},
#  '\ufeff96058202955': {'name': 'Mercat Dominical de Sant Antoni',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '35122',
#   'modified': '44755,4564',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349706,
#   'addresses_road_name': "C Comte d'Urgell",
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 10,
#   'addresses_neighborhood_name': 'Sant Antoni',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8011,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 189742,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132300',
#   'values_outstanding': 'VERDADERO',
#   'values_description': 'Mercat de Sant Antoni',
#   'secondary_filters_id': 58731069,
#   'secondary_filters_name': 'Mercats i fires al carrer',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats i fires al carrer',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29907E+16',
#   'geo_epgs_25831_y': '4,58123E+15',
#   'geo_epgs_4326_x': '4,13796E+15',
#   'geo_epgs_4326_y': '2,16174E+15',
#   'padro': {'Dones': 20253, 'Homes': 18447, 'Total': 38700}},
#  '\ufeff92086009445': {'name': 'Mercat de La Barceloneta',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31044',
#   'modified': '44825,41282',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 260908,
#   'addresses_road_name': 'Plaça del Poeta Boscà',
#   'addresses_start_street_number': 1,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 3,
#   'addresses_neighborhood_name': 'la Barceloneta',
#   'addresses_district_id': 1,
#   'addresses_district_name': 'Ciutat Vella',
#   'addresses_zip_code': 8003,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162818,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132304',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,3221E+16',
#   'geo_epgs_25831_y': '4,58129E+15',
#   'geo_epgs_4326_x': '4,13802E+15',
#   'geo_epgs_4326_y': '2,18928E+14',
#   'padro': {'Dones': 7647, 'Homes': 7478, 'Total': 15125}},
#  '\ufeff92086009776': {'name': 'Mercat del Guinardó',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,42299',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 334403,
#   'addresses_road_name': 'C Teodor Llorente',
#   'addresses_start_street_number': 10,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 35,
#   'addresses_neighborhood_name': 'el Guinardó',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8041,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162004,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132332',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31452E+15',
#   'geo_epgs_25831_y': '4,58561E+15',
#   'geo_epgs_4326_x': '4,14192E+16',
#   'geo_epgs_4326_y': '2,17972E+15',
#   'padro': {'Dones': 19865, 'Homes': 17460, 'Total': 37325}},
#  '\ufeff92086009779': {'name': 'Mercat de La Guineueta',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44776,56573',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 351901,
#   'addresses_road_name': 'Passeig de Valldaura',
#   'addresses_start_street_number': 186,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 48,
#   'addresses_neighborhood_name': 'la Guineueta',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8042,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162006,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132338',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30681E+15',
#   'geo_epgs_25831_y': '4,58779E+15',
#   'geo_epgs_4326_x': '4,14387E+15',
#   'geo_epgs_4326_y': '2,17025E+15',
#   'padro': {'Dones': 8213, 'Homes': 7054, 'Total': 15267}},
#  '\ufeff92086009788': {'name': 'Mercat del Clot',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,4115',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 209004,
#   'addresses_road_name': 'Pl Mercat',
#   'addresses_start_street_number': 26,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 65,
#   'addresses_neighborhood_name': 'el Clot',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8018,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162417,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132306',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,32186E+15',
#   'geo_epgs_25831_y': '4,58433E+14',
#   'geo_epgs_4326_x': '4,14076E+15',
#   'geo_epgs_4326_y': '2,18864E+16',
#   'padro': {'Dones': 13956, 'Homes': 12803, 'Total': 26759}},
#  '\ufeff92086009791': {'name': 'Mercat del Poblenou',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,49295',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 349003,
#   'addresses_road_name': 'Pl Unió',
#   'addresses_start_street_number': 25,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 68,
#   'addresses_neighborhood_name': 'el Poblenou',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8005,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 161888,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132309',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,33582E+16',
#   'geo_epgs_25831_y': '4,58358E+15',
#   'geo_epgs_4326_x': '4,1401E+15',
#   'geo_epgs_4326_y': '2,20543E+16',
#   'padro': {'Dones': 17675, 'Homes': 16736, 'Total': 34411}},
#  '\ufeff92086009793': {'name': 'Mercat de Provençals',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44768,43597',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 208205,
#   'addresses_road_name': 'Carrer de Menorca',
#   'addresses_start_street_number': 19,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 72,
#   'addresses_neighborhood_name': 'Sant Martí de Provençals',
#   'addresses_district_id': 10,
#   'addresses_district_name': 'Sant Martí',
#   'addresses_zip_code': 8020,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162487,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '662002663',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,32853E+15',
#   'geo_epgs_25831_y': '4,58563E+15',
#   'geo_epgs_4326_x': '4,14195E+15',
#   'geo_epgs_4326_y': '2,19649E+16',
#   'padro': {'Dones': 13958, 'Homes': 12271, 'Total': 26229}},
#  '\ufeff92086009774': {'name': "Mercat de l'Estrella",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44753,5782',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 144306,
#   'addresses_road_name': 'Carrer de Pi i Margall',
#   'addresses_start_street_number': 73,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 32,
#   'addresses_neighborhood_name': "el Camp d'en Grassot i Gràcia Nova",
#   'addresses_district_id': 6,
#   'addresses_district_name': 'Gràcia',
#   'addresses_zip_code': 8024,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162002,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132315',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30128E+15',
#   'geo_epgs_25831_y': '4,5846E+15',
#   'geo_epgs_4326_x': '4,14099E+16',
#   'geo_epgs_4326_y': '2,16399E+16',
#   'padro': {'Dones': 19121, 'Homes': 16231, 'Total': 35352}},
#  '\ufeff92086009777': {'name': "Mercat de Vall d'Hebron -Taxonera",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44824,42722',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 352507,
#   'addresses_road_name': "Pg Vall d'Hebron",
#   'addresses_start_street_number': 130,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 38,
#   'addresses_neighborhood_name': 'la Teixonera',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8035,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162005,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132344',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,28343E+16',
#   'geo_epgs_25831_y': '4,58619E+15',
#   'geo_epgs_4326_x': '4,14241E+15',
#   'geo_epgs_4326_y': '2,14245E+15',
#   'padro': {'Dones': 6248, 'Homes': 5796, 'Total': 12044}},
#  '\ufeff92086009778': {'name': "Mercat d'Horta",
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44824,42873',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 329505,
#   'addresses_road_name': 'Carrer del Tajo',
#   'addresses_start_street_number': 75,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 43,
#   'addresses_neighborhood_name': 'Horta',
#   'addresses_district_id': 7,
#   'addresses_district_name': 'Horta-Guinardó',
#   'addresses_zip_code': 8032,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162391,
#   'values_attribute_id': 20039,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Servei a domicili',
#   'values_value': '934204858',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,29782E+15',
#   'geo_epgs_25831_y': '4,58679E+13',
#   'geo_epgs_4326_x': '4,14296E+15',
#   'geo_epgs_4326_y': '2,15961E+16',
#   'padro': {'Dones': 14918, 'Homes': 13137, 'Total': 28055}},
#  '\ufeff92086009780': {'name': 'Mercat de La Mercè',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44771,46113',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 119003,
#   'addresses_road_name': 'Passeig de Fabra i Puig',
#   'addresses_start_street_number': 270,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 46,
#   'addresses_neighborhood_name': 'el Turó de la Peira',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8031,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162007,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132340',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,30952E+15',
#   'geo_epgs_25831_y': '4,58688E+15',
#   'geo_epgs_4326_x': '4,14305E+16',
#   'geo_epgs_4326_y': '2,1736E+16',
#   'padro': {'Dones': 8609, 'Homes': 7577, 'Total': 16186}},
#  '\ufeff92086009784': {'name': 'Mercat del Bon Pastor',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '31064',
#   'modified': '44728,49155',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 295709,
#   'addresses_road_name': 'C Sant Adrià',
#   'addresses_start_street_number': 154,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 59,
#   'addresses_neighborhood_name': 'el Bon Pastor',
#   'addresses_district_id': 9,
#   'addresses_district_name': 'Sant Andreu',
#   'addresses_zip_code': 8030,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 162011,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132333',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,33679E+15',
#   'geo_epgs_25831_y': '4,58746E+15',
#   'geo_epgs_4326_x': '4,1436E+15',
#   'geo_epgs_4326_y': '2,20617E+15',
#   'padro': {'Dones': 6870, 'Homes': 6860, 'Total': 13730}},
#  '\ufeff99400069155': {'name': 'Mercat del Fort Pienc',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '37958,58828',
#   'modified': '44732,38674',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 701420,
#   'addresses_road_name': 'Pl Fort Pienc',
#   'addresses_start_street_number': 3,
#   'addresses_end_street_number': nan,
#   'addresses_neighborhood_id': 5,
#   'addresses_neighborhood_name': 'el Fort Pienc',
#   'addresses_district_id': 2,
#   'addresses_district_name': 'Eixample',
#   'addresses_zip_code': 8013,
#   'addresses_town': 'BARCELONA',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 208673,
#   'values_attribute_id': 20001,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Tel.',
#   'values_value': '934132316',
#   'values_outstanding': 'VERDADERO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '4,31663E+15',
#   'geo_epgs_25831_y': '4,58302E+15',
#   'geo_epgs_4326_x': '4,13958E+15',
#   'geo_epgs_4326_y': '2,18254E+15',
#   'padro': {'Dones': 17443, 'Homes': 16002, 'Total': 33445}},
#  '\ufeff99400695137': {'name': 'Mercat de Núria',
#   'institution_id': nan,
#   'institution_name': nan,
#   'created': '44754,5899',
#   'modified': '44760,37418',
#   'addresses_roadtype_id': nan,
#   'addresses_roadtype_name': nan,
#   'addresses_road_id': 275600,
#   'addresses_road_name': 'Avinguda dels Rasos de Peguera',
#   'addresses_start_street_number': 186,
#   'addresses_end_street_number': 186.0,
#   'addresses_neighborhood_id': 55,
#   'addresses_neighborhood_name': 'Ciutat Meridiana',
#   'addresses_district_id': 8,
#   'addresses_district_name': 'Nou Barris',
#   'addresses_zip_code': 8033,
#   'addresses_town': 'Barcelona',
#   'addresses_main_address': 'VERDADERO',
#   'addresses_type': nan,
#   'values_id': 460429,
#   'values_attribute_id': 20006,
#   'values_category': 'Telèfons',
#   'values_attribute_name': 'Informació',
#   'values_value': '934132890',
#   'values_outstanding': 'FALSO',
#   'values_description': nan,
#   'secondary_filters_id': 58731068,
#   'secondary_filters_name': 'Mercats municipals',
#   'secondary_filters_fullpath': 'Planol BCN >> Mercats i centres comercials >> Mercats i centres comercials >> Mercats municipals',
#   'secondary_filters_tree': 651,
#   'secondary_filters_asia_id': '6,5103E+13',
#   'geo_epgs_25831_x': '430903145',
#   'geo_epgs_25831_y': '4590148469',
#   'geo_epgs_4326_x': '4,146E+15',
#   'geo_epgs_4326_y': '2,17264E+16',
#   'padro': {'Dones': 5688, 'Homes': 5464, 'Total': 11152}}}

# %%
#Visualizar el diccionario resultante. ¿Cuántos registros tiene? ¿Coincide este valor con el número de instancias del dataframe df_empleos?

len(dict_mercados) == len(df_mercados)
# Out:
# True

# %%
# Cuántas mujeres hay en el barrio que está el mercado con register_id=92086009450

dict_mercados['\ufeff92086009450']['padro']['Dones']
# Out:
# 28118

# %%
# ¿En qué calle esta el mercado cuyo register_id=﻿92086009457?

dict_mercados['\ufeff92086009457']['addresses_road_name']
# Out:
# 'Travessera de les Corts'

# %%
#Guardar el diccionario en un fichero con formato .json.

json_mercados = json.dumps(dict_mercados)

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Existen diferentes repositorios o páginas web que permiten el acceso a múltiples datasets con finalidades academicas o de consulta ciudadana. Posibles fuentes abiertas de información podrían ser las siguientes:
#
# - OpenData de ayuntamientos: Valencia, Madrid, Santander…
# - https://archive.ics.uci.edu/ml/datasets.php
# - https://www.kaggle.com/datasets
# - https://bigml.com/gallery/datasets
# - https://toolbox.google.com/datasetsearch
#
# **En esta actividad se pide que se exploren los repositorios facilitados anteriormente, y se escojan dos datasets que contengan al menos dos variables numéricas y dos categóricas.**
#
# **Para cada uno de estos datasets se solicita:**
#
# - **Indicar cuál ha sido la motivación por la que se han escogido los dos datasets. Esta cuestión es de respuesta obligatoria para evaluar la originalidad de la realización del ejercicio.**
# - **Describir el datatet.**
# - **Describir a qué se refieren las columnas que forman el dataset.¿Que representan?**
# - **¿De qué tipo son cada una de las columnas o variables del dataset?**
# - **Cargar el dataframe y revisar que los tipos de datos se hayan definido correctamente. Si no están bien definidos, cambiar el tipo de dato que corresponda**.
# - **Visualizar las primeras filas del dataframe**.
# - **Hacer una propuesta de anális o objetivo de análisis que se podria llevar a cabo con el dataset. ¿Que tipo de conclusiones podriamos obtener?**
#
#
#
#
# ---

# %% [markdown]
# - **Indicar cuál ha sido la motivación por la que se han escogido los dos datasets. Esta cuestión es de respuesta obligatoria para evaluar la originalidad de la realización del ejercicio**

# %% [markdown]
# _Respuesta:_
# - He elegido Data Breaches (https://www.kaggle.com/datasets/thedevastator/data-breaches-a-comprehensive-list), al cual llamaré A, y (https://www.kaggle.com/datasets/cedricaubin/ai-ml-salaries), al que llamaré B
# - Motivación: de las fuentes de información presentada, Kaggle es la única que valora la "usability" de sus datatsets. Así pues, he elegido 2 datasets con la máxima posible y que cumplieran con los criterios que solicita el ejercicio... además, para A, quería saber si mi antigua organización, la cual sufrió un crackeo, aparece en la lista de Data Breaches (resulta que no). Para B, pues siempre está bien saber lo que se gana en el sector en el que quizá uno acabe trabajando

# %% [markdown]
# - **Describir el datatet**

# %% [markdown]
# _Respuesta:_
# - A es un dataset sobre brechas de seguridad en el entorno digital
# - B es un dataset sobre salarios en el sector de la IA

# %% [markdown]
# - **Describir a qué se refieren las columnas que forman el dataset.¿Que representan?**

# %% [markdown]
# _Respuesta:_
# - Para A hay: Id (número identificativo), Entity (la empresa que sufre la brecha), Year (año), Records (cuántos datos se comprometen), Organization type (sector de la empresa), Method (cómo se produce la brecha) y Sources (sirve al autor del dataset para identificar sus fuentes. Por cada número entre [], hay una fuente distinta. A más fuentes, más fiable será un dato)
# - Para B hay: work_year (año), experience_level (nivel de experiencia; puede ser senior, junior, etc.), employment_type (a tiempo parcial, a tiempo completo...), job_title (rol), salary (salario), salary_currency (tipo de cambio), salary_in_usd (salario en dólares), employee_residence (residencia del empleado), remote_ratio (horas de teletrabajo) y company_location (ubicación de la empresa)

# %% [markdown]
# - **De qué tipo son cada una de las columnas o variables del dataset?**

# %% [markdown]
# _Respuesta:_
# - Para A hay: Id (int), Entity (str), Year (int), Records (int), Organization type (str), Method (str) y Sources (str)
# - Para B hay: work_year (int), experience_level (str), employment_type (str), job_title (str), salary (int), salary_currency (str), salary_in_usd (int), employee_residence (str), remote_ratio (int) y company_location (str)

# %% [markdown]
# - **Cargar el dataframe y revisar que los tipos de datos se hayan definido correctamente.**

# %%
df_breaches = pd.read_csv(r'.\breaches.csv')
df_salaries = pd.read_csv(r'.\salaries.csv')

df_breaches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         352 non-null    int64
#  1   Entity             352 non-null    object
#  2   Year               352 non-null    object
#  3   Records            350 non-null    object
#  4   Organization type  352 non-null    object
#  5   Method             351 non-null    object
#  6   Sources            350 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 19.4+ KB

# %%
df_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1332 entries, 0 to 1331
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           1332 non-null   int64
#  1   experience_level    1332 non-null   object
#  2   employment_type     1332 non-null   object
#  3   job_title           1332 non-null   object
#  4   salary              1332 non-null   int64
#  5   salary_currency     1332 non-null   object
#  6   salary_in_usd       1332 non-null   int64
#  7   employee_residence  1332 non-null   object
#  8   remote_ratio        1332 non-null   int64
#  9   company_location    1332 non-null   object
#  10  company_size        1332 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 114.6+ KB

# %% [markdown]
# _Respuesta:_
# - Para A los integers no, para B sí

# %% [markdown]
# - **Visualizar las primeras filas del dataframe.**

# %%
# Visualizar las primeras filas del dataframe.

df_breaches.head()
# Out:
#    Unnamed: 0                      Entity  Year    Records  Organization type  \
# 0           0       21st Century Oncology  2016    2200000         healthcare
# 1           1                       500px  2020   14870304  social networking
# 2           2       Accendo Insurance Co.  2020     175350         healthcare
# 3           3  Adobe Systems Incorporated  2013  152000000               tech
# 4           4                  Adobe Inc.  2019    7500000               tech
#
#           Method   Sources
# 0         hacked    [5][6]
# 1         hacked       [7]
# 2  poor security    [8][9]
# 3         hacked      [10]
# 4  poor security  [11][12]

# %%
df_salaries.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT  Machine Learning Engineer
# 1       2022               MI              FT  Machine Learning Engineer
# 2       2022               MI              FT             Data Scientist
# 3       2022               MI              FT             Data Scientist
# 4       2022               MI              FT             Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  130000             USD         130000                 US             0
# 1   90000             USD          90000                 US             0
# 2  120000             USD         120000                 US           100
# 3  100000             USD         100000                 US           100
# 4   85000             USD          85000                 US           100
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %% [markdown]
# - **Hacer una propuesta de análisis o objetivo de análisis que se podria llevar a cabo con el dataset. ¿Que tipo de conclusiones podriamos obtener?**

# %% [markdown]
# _Respuesta:_
# - Para A, podríamos ver en qué sector se producen el mayor número de brechas. Luego, veríamos qué tipo de brecha es más numeroso en ese sector. Con esa información, podríamos llamar a las empresas de ese sector y decirles que vigilen con tal o cual método de hackeo
# - Para B, podríamos ver dónde cobra más un data scientist y mudarnos allí

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Un caso particular de JSON, fuertemente utilizados en datos con referencias geográficas,  son los GEO-JSON. Este tipo de datos tienen un formato JSON, donde uno de los campos son latitud y longitud (o coordenadas x, y, si se usa otro tipo de sistema de referencia). Este tipo de dato con información georeferenciada también puede encontrarse registrada en formato csv, siempre que aparezcan los campos pertinentes a la geolocalización (latitud y longitud y/o coordenada x y coordenada y).
#
# **En este ejercicio vamos a trabajar con un dataset donde aparecen geolocalizadas los refugios climáticos de Barcelona (`xarxa_refugis_climatics_bna.json`). Con este dataset, considerando las coordenadas X, Y asociadas con cada refugio, representaremos en el mapa donde están ubicados estos refugios.**
#
# **Para la realización del ejercicio se pide:**
#
#
# - **Cargar los datos.**
#
# - **A partir de los datos en formato JSON, crear un dataframe que tenga las siguientes columnas:`[Name,	start_street_number,	latitud,	longitud]`**
#   - La latitud y longitud deberán ser obtenidas a partir de las coordenadas que se indican en el json.
#
# - **Representar en el mapa, donde existe un refugio climático e indicar como tooltip el nombre del refugio climático. Para ello, se solicita completar el código que se facilita y ayudarse del ejemplo que se muestra para dos puntos.**
#
# - **Repetir la representación anterior, pero modificando el color del marcador de acuerdo con esta codificación:**
#
#   -	**verde: campo 'start_street_number' par**
#   - **azul: campo 'start_street_number' impar**
#
#
#
#
#
#
#
#
# ---

# %% [markdown]
# Para hacer la representación en el mapa, se va a utilizar la librería folium, la cual es una librería muy intuitiva de utilizar para hacer pequeñas representacions geograficas (https://python-visualization.github.io/folium/index.html).
#
# La particularidad de esta librería es que las localizaciones deben estar dadas en latitud y longitud. Por tanto, previamente a representar las localizaciones hay que asegurarse de que se disponen de estos valores o, en caso contrario, hacer una transformación de sistema de referencia. Para ello, se puede utilizar la librería pyproj (https://pypi.org/project/pyproj/), como se indica a continuación.

# %% [markdown]
# _Ejemplo representación dos puntos en mapa con folium, haciendo transformación de sistema de coordenadas:_

# %%
## Tansformación de las coordenadas de los puntos a lat,lon
warnings.filterwarnings("ignore")

# configurar las proyecciones
pj_target = proj.Proj(init='epsg:4326') # proyeccion objetivo
pj_data  = proj.Proj(init='epsg:25830') # proyeccion de los datos

x1= 726882.491
y1= 4370748.231
lon1, lat1 = proj.transform(pj_data, pj_target , x1,y1)

x2= 727265.727
y2= 4371653.468
lon2, lat2 = proj.transform(pj_data, pj_target , x2,y2)

# %%
# Cargar folium y crear data
tooltip1='punto1'
tooltip2='punto2'

m = folium.Map(location=[lat1, lon1])
folium.Marker([lat1, lon1], icon=folium.Icon(color='red'), tooltip=tooltip1).add_to(m)
folium.Marker([lat2, lon2], icon=folium.Icon(color='blue'), tooltip=tooltip2).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d7624ee2d260519a4835791fc9c00d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d7624ee2d260519a4835791fc9c00d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d7624ee2d260519a4835791fc9c00d5 = L.map(
#                 &quot;map_7d7624ee2d260519a4835791fc9c00d5&quot;,
#                 {
#                     center: [39.45642926416408, -0.36301435701318363],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b977421d6b8c3cb144e5426ffd28a000 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d7624ee2d260519a4835791fc9c00d5);
#
#
#             var marker_ec35f3715f81089405d75ca2a4ff9b47 = L.marker(
#                 [39.45642926416408, -0.36301435701318363],
#                 {}
#             ).addTo(map_7d7624ee2d260519a4835791fc9c00d5);
#
#
#             var icon_11faa1ec36250b32affc24d2f84f10b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ec35f3715f81089405d75ca2a4ff9b47.setIcon(icon_11faa1ec36250b32affc24d2f84f10b0);
#
#
#             marker_ec35f3715f81089405d75ca2a4ff9b47.bindTooltip(
#                 `&lt;div&gt;
#                      punto1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_57ded186f658c6d5689c5e6e1494ff08 = L.marker(
#                 [39.464476294623736, -0.3582563370036071],
#                 {}
#             ).addTo(map_7d7624ee2d260519a4835791fc9c00d5);
#
#
#             var icon_e330e84b2624f98e17d2c4ff712be30e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_57ded186f658c6d5689c5e6e1494ff08.setIcon(icon_e330e84b2624f98e17d2c4ff712be30e);
#
#
#             marker_57ded186f658c6d5689c5e6e1494ff08.bindTooltip(
#                 `&lt;div&gt;
#                      punto2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
#
#
#
# ---

# %%
#Cargar datos JSON
json_file_path = r'./xarxa_refugis_climatics_bna.json'
with open(json_file_path, 'r', encoding="utf8") as j:
     contents = json.load(j)

# %%
#Crear el dataframe - **A partir de los datos en formato JSON, crear un dataframe que tenga las siguientes columnas:`[Name,	start_street_number,	latitud,	longitud]`** 


list_refugi = []
for refugi in contents:
    name = refugi['name']
    start_street_number = refugi['addresses'][0]['start_street_number']
    longitud, latitud = refugi['addresses'][0]['location']['geometries'][0]['coordinates']

    dict_refugi = {'name': name,
                    'start_street_number': start_street_number,
                    'latitud': latitud,
                    'longitud': longitud
                    }
    
    list_refugi.append(dict_refugi)

df_maps = pd.DataFrame(list_refugi)

df_maps
# Out:
#                                         name  start_street_number  \
# 0       Centre Esportiu Municipal Can Ricart                  8.0
# 1                     El Centre de la Platja                 25.0
# 2         Centre Esportiu Municipal Sardenya                549.0
# 3                  Institut Escola Antaviana                 12.0
# 4      Centre Esportiu Municipal Bac de Roda                 23.0
# ..                                       ...                  ...
# 196        Biblioteca El Carmel - Juan Marsé                135.0
# 197         Centre Esportiu Municipal Mundet                  NaN
# 198               Centre Cívic Casa Orlandai                 23.0
# 199  Casal de Gent Gran de la Trinitat Vella                 85.0
# 200            Casal de Gent Gran Can Novell                 29.0
#
#           latitud       longitud
# 0    4.580975e+06  430668.632097
# 1    4.581612e+06  432693.236283
# 2    4.584859e+06  429983.783948
# 3    4.588837e+06  431388.787492
# 4    4.585073e+06  432647.578034
# ..            ...            ...
# 196  4.585841e+06  429397.714434
# 197  4.587574e+06  428389.080859
# 198  4.583350e+06  426828.226923
# 199  4.589022e+06  432303.982577
# 200  4.581553e+06  427582.425000
#
# [201 rows x 4 columns]

# %% [markdown]
# ---

# %%
pj_target = proj.Proj(init='epsg:4326') 
pj_data  = proj.Proj(init='epsg:25831') # He ido a la página del ajuntament y he visto que aquí va un 1, en lugar del 0 que hay en el ejemplo
                                        #(https://opendata-ajuntament.barcelona.cat/data/ca/dataset/xarxa-refugis-climatics/resource/7ecae024-6cb2-427d-b2d0-e170500e2a38)

lon1, lat1 = proj.transform(pj_data, pj_target , df_maps['longitud'][0], df_maps['latitud'][0])
m = folium.Map(location=[lat1, lon1])

for index, tupla in enumerate(zip(df_maps['latitud'], df_maps['longitud'], df_maps['start_street_number'], df_maps['name'])):
    latitud = tupla[0]
    longitud = tupla[1]
    start_street_number = tupla[2]
    name = tupla[3]
    lon1, lat1 = proj.transform(pj_data, pj_target , longitud, latitud)
    tooltip = f'Punto{index}: {name}'
    color = 'red'
    if start_street_number % 2 == 0: 
        color = 'green' 
    folium.Marker([lat1, lon1], icon=folium.Icon(color=color), tooltip=tooltip).add_to(m)
    folium.Marker([lat2, lon2], icon=folium.Icon(color=color), tooltip=tooltip).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61868a66b766879b081f8480f83c3a93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61868a66b766879b081f8480f83c3a93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61868a66b766879b081f8480f83c3a93 = L.map(
#                 &quot;map_61868a66b766879b081f8480f83c3a93&quot;,
#                 {
#                     center: [41.37731084646637, 2.1708804895915366],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4dab8b42f2b659e4a27d869014433622 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_61868a66b766879b081f8480f83c3a93);
#
#
#             var marker_7d64b955e045da7e4210e3582e6154b9 = L.marker(
#                 [41.37731084646637, 2.1708804895915366],
#                 {}
#             ).addTo(map_61868a66b766879b081f8480f83c3a93);
#
#
#             var icon_303997f569d471e38920b3c1128aac55 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7d64b955e045da7e4210e3582e6154b9.setIcon(icon_303997f569d471e38920b3c1128aac55);
#
#
#             marker_7d64b955e045da7e4210e3582e6154b9.bindTooltip(
#                 `&lt;div&gt;
#                      Punto0: Centre Esportiu Municipal Can Ricart
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_db27f5fbd7d4de345fa0721356200c4e = L.marker(
#                 [39.464476294623736, -0.3582563370036071],
#                 {}
#             ).addTo(map_61868a66b766879b081f8480f83c3a93);
#
#
#             var icon_f58b7fb81f9f53d3b2ba914779685d83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db27f5fbd7d4de345fa0721356200c4e.setIcon(icon_f58b7fb81f9f53d3b2ba914779685d83);
#
#
#             marker_db27f5fbd7d4de345fa0721356200c4e.bindTooltip(
#                 `&lt;div&gt;
#                      Punto0: Centre Esportiu Municipal Can Ricart
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_933fe691b90b16f201e9f26058160cd4 = L.marker(
#                 [41.38321872603324, 2.1950192542461915],
#                 {}
#             ).addTo(map_61868a66b766879b081f8480f83c3a93);
#
#
#             var icon_7f5eca89321094bc7ffb848e7fe6e7f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_933fe691b90b16f201e9f26058160cd4.setIcon(icon_7f5eca89321094bc7ffb848e7fe6e7f8);
#
#
#             marker_933fe691b90b16f201e9f26058160cd4.bindTooltip(
#                 `&lt;div&gt;
#                      Punto1: El Centre de la Platja
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e48e52bce3522c3f412851bcf1e500ca = L.marker(
#                 [39.464476294623736, -0.3582563370036071],
#                 {}
#             ).addTo(map_61868a66b766879b081f8480f83c3a93);
#
#
#             var icon_bb8a48b215dae225e86657aa9a27e370 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e48e52bce3522c3f412851bcf1e500ca.setIcon(icon_bb8a48b215dae225e86657aa9a27e370);
#
#
#             marker_e48e52bce3522c3f412851bcf1e500ca.bindTooltip(
#                 `&lt;div&gt;
#                      Punto1: El Centre de la Platja
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_67b6c442734430f64b0e88736716f47e = L.marker(
#                 [41.412233568929814, 2.1622422992641552],
#                 {}
#             ).addTo(map_61868a66b766879b081f8480f83c3a93);
#
#
#             var icon_703c4727c02aca08f30fd9771ac4c98b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;:

# %% [markdown]
# **¿Són correctas las geolocalizaciones si sabemos que son los refugios climáticos de Barcelona? A qué crees que puede deberse?**

# %%
# Son correctas. Pues a que las he puesto bien
